# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException,ElementNotInteractableException,TimeoutException
import requests
import re

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = 'https://timesofindia.indiatimes.com/archive/year-2021,month-1.cms'
driver.get(url)

# %%
urls=[]
for j in driver.find_elements_by_xpath('/html/body/center/div[1]/div[3]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[1]/td/span/div/table/tbody/tr/td/a'):
    urls.append(j.get_attribute("href"))

# %%
url=[]
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[1]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[2]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[3]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[3]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[4]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[5]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[6]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[7]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[8]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[9]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[10]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[11]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[12]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[13]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[14]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[15]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[16]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[17]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[18]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[19]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[20]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[21]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[22]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[23]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[24]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[25]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[26]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[27]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[28]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[29]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
df1 = pd.DataFrame({})
df1["url"]=url
df.to_csv('scraped url1.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-5e664b3f93c3> in <module>
#       1 df1 = pd.DataFrame({})
#       2 df1["url"]=url
# ----> 3 df.to_csv('scraped url1.csv')
#
# NameError: name 'df' is not defined

# %%
df1=pd.read_csv('scraped url1.csv')

# %%
date=[]
author=[]
vertical=[]
headline=[]
description=[]

# %%
for i in df1.url:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date.append(a.text)
        
    except NoSuchElementException:
        date.append(' ')

        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a")
        author.append(b.text)
        
    except NoSuchElementException:
        author.append(' ')
    
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical.append(c.text)  
    except NoSuchElementException:
        vertical.append(' ')
    
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline.append(d.text) 
            
    except NoSuchElementException:
        headline.append(' ') 
    
        
        
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description.append(e.text) 
        
    except NoSuchElementException:
        description.append(' ')

# %%
df= pd.DataFrame({})
df["Date"] = date
df["Author"] = author
df["Vertical"] = vertical
df["Headline"] = headline
df["Description"] = description
df.to_csv("news 1.csv")

# %%
url=[]
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[30]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[31]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[32]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[33]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[34]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[35]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[36]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[37]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[38]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[39]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[40]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[4]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[42]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[43]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[44]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[45]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[46]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[47]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[48]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[49]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[50]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[51]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[52]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[53]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[54]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[55]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[56]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[57]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[58]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[59]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[60]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[61]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[62]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[63]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[64]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[65]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[67]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[68]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[69]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[70]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[71]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[72]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[73]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[74]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[75]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[76]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[77]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[78]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[79]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[80]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[81]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[82]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[83]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[84]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[85]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[86]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[87]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[88]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[89]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[90]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[91]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[92]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[93]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[94]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[94]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[95]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[96]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[97]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[98]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[99]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[100]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[101]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[102]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[103]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[104]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[105]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[106]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[107]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[108]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[109]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[110]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[111]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[112]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[113]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[114]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[115]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[116]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[117]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[118]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[119]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[120]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
df = pd.DataFrame({})
df["url"]=url
df.to_csv('scraped url')

# %%
df=pd.read_csv('scraped url')

# %%
df.shape
# Out:
# (2821, 2)

# %%
date1=[]
author1=[]
vertical1=[]
headline1=[]
description1=[]

# %%
for i in df.url[0:500]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
        
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
        
    except NoSuchElementException:
        description1.append(' ')

# %%
df = pd.DataFrame({})
df["Date"] = date1
df["Author"] = author1
df["Vertical"] = vertical1
df["Headline"] = headline1
df["Description"] = description1

# %%
df.to_csv("news2.csv")

# %%
for i in df.url[500:1000]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
        
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
        
    except NoSuchElementException:
        description1.append(' ')

# %%
df2 = pd.DataFrame({})
df2["Date"] = date1[500:1000]
df2["Author"] = author1[500:1000]
df2["Vertical"] = vertical1[500:1000]
df2["Headline"] = headline1[500:1000]
df2["Description"] = description1[500:1000]
df2.to_csv("news3.csv")

# %%
for i in df.url[1000:1500]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
        
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
        
    except NoSuchElementException:
        description1.append(' ')

# %%
df2 = pd.DataFrame({})
df2["Date"] = date1[1000:1500]
df2["Author"] = author1[1000:1500]
df2["Vertical"] = vertical1[1000:1500]
df2["Headline"] = headline1[1000:1500]
df2["Description"] = description1[1000:1500]
df2.to_csv("news4.csv")

# %%
for i in df.url[1500:2000]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
                            
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)          
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
        
    except NoSuchElementException:
        headline1.append(' ')
        
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
        
    except NoSuchElementException:
        description1.append(' ')

# %%
df5 =pd.DataFrame({})
df5["Date"] = date1[1500:2000]
df5["Author"] = author1[1500:2000]
df5["Vertical"] = vertical1[1500:2000]
df5["Headline"] = headline1[1500:2000]
df5["Description"] = description1[1500:2000]
df5.to_csv("news5.csv")

# %%
for i in df.url[2000:2822]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df5 =pd.DataFrame({})
df5["Date"] = date1[2000:2822]
df5["Author"] = author1[2000:2822]
df5["Vertical"] = vertical1[2000:2822]
df5["Headline"] = headline1[2000:2822]
df5["Description"] = description1[2000:2822]
df5.to_csv("news6.csv")

# %%
url=[]
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[121]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[122]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[123]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[124]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[125]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[126]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[127]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[128]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[129]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[130]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[131]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[132]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[133]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[134]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[135]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[136]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[137]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[138]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[139]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[140]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[141]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[142]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[143]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[144]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[145]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[146]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[147]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[148]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[149]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[150]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[151]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[152]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[153]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[154]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[155]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[156]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[157]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[158]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[159]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[160]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[161]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[162]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[163]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[164]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[165]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[166]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[167]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[168]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[169]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[170]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[171]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[172]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[173]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[174]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[175]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[176]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[177]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[178]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[179]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[180]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[181]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[182]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[183]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[184]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[185]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[186]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[187]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[188]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[189]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[190]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[191]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[192]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[193]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[194]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[195]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[196]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[197]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[198]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[199]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[200]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
df1 = pd.DataFrame({})
df1["url"]=url
df1.to_csv('scraped urls.csv')

# %%
df=pd.read_csv('scraped urls.csv')

# %%
df.shape
# Out:
# (2511, 2)

# %%
date1=[]
author1=[]
vertical1=[]
headline1=[]
description1=[]

# %%
for i in df.url[0:800]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|//div[@class='_36ns3']/div[2]/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
for i in df.url[800:1600]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
for i in df.url[1600:2512]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df6 =pd.DataFrame({})
df6["Date"] = date1
df6["Author"] = author1
df6["Vertical"] = vertical1
df6["Headline"] = headline1
df6["Description"] = description1
df6.to_csv("news6.csv")

# %%
df7 =pd.DataFrame({})
df7["Date"] = date1
df7["Author"] = author1
df7["Vertical"] = vertical1
df7["Headline"] = headline1
df7["Description"] = description1
df7.to_csv("news7.csv")

# %%
df8 =pd.DataFrame({})
df8["Date"] = date1
df8["Author"] = author1
df8["Vertical"] = vertical1
df8["Headline"] = headline1
df8["Description"] = description1
df8.to_csv("news8.csv")

# %%
url=[]
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[201]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[202]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[203]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[204]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[205]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[206]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[207]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[208]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
df1 = pd.DataFrame({})
df1["url"]=url
df1.to_csv('scraped urls4.csv')

# %%
df = pd.read_csv("scraped urls4.csv")

# %%
date=[]
author=[]
vertical=[]
headline=[]
description=[]

# %%
for i in df.url:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date.append(a.text)
        
    except NoSuchElementException:
        date.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        author.append(b.text)
        
    except NoSuchElementException:
        author.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical.append(c.text)  
    except NoSuchElementException:
        vertical.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline.append(d.text) 
            
    except NoSuchElementException:
        headline.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description.append(e.text) 
    except NoSuchElementException:
        description.append(' ')

# %%
df= pd.DataFrame({})
df["Date"] = date
df["Author"] = author
df["Vertical"] = vertical
df["Headline"] = headline
df["Description"] = description
df.to_csv("news1a.csv")

# %%
url=[]
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[209]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[210]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[211]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[212]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[213]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[214]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
url=[]
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[215]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[216]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[217]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[218]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[219]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[220]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[221]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[222]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[223]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[224]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[225]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[226]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[227]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[228]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[229]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[230]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[231]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[232]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[233]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[234]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[235]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[236]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[237]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[238]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[239]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
url=[]
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[240]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[241]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[242]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[243]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[244]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[245]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[246]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[247]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[248]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[249]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
for i in urls[5:36]:
    driver.get(i)
    time.sleep(3)
    
    try:
        j = driver.find_element_by_xpath('/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[2]/td[1]/span/a[250]')
        url.append(j.get_attribute("href"))
    except NoSuchElementException:
        url.append(' ')

# %%
df1 = pd.DataFrame({})
df1["url"]=url
df1.to_csv('scraped urls5.csv')

# %%
date1=[]
author1=[]
vertical1=[]
headline1=[]
description1=[]

# %%
for i in df.url[0:100]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df9 =pd.DataFrame({})
df9["Date"] = date1
df9["Author"] = author1
df9["Vertical"] = vertical1
df9["Headline"] = headline1
df9["Description"] = description1
df9.to_csv("news9.csv")

# %%
for i in df.url[100:300]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df10 =pd.DataFrame({})
df10["Date"] = date1
df10["Author"] = author1
df10["Vertical"] = vertical1
df10["Headline"] = headline1
df10["Description"] = description1
df10.to_csv("news10.csv")

# %%
for i in df.url[500:600]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df11 =pd.DataFrame({})
df11["Date"] = date1[6:]
df11["Author"] = author1[6:]
df11["Vertical"] = vertical1[6:]
df11["Headline"] = headline1[6:]
df11["Description"] = description1[6:]
df11.to_csv("news11.csv")

# %%
for i in df.url[600:700]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df12 =pd.DataFrame({})
df12["Date"] = date1
df12["Author"] = author1
df12["Vertical"] = vertical1
df12["Headline"] = headline1
df12["Description"] = description1
df12.to_csv("news12.csv")

# %%
for i in df.url[700:800]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df13 =pd.DataFrame({})
df13["Date"] = date1
df13["Author"] = author1
df13["Vertical"] = vertical1
df13["Headline"] = headline1
df13["Description"] = description1
df13.to_csv("news13.csv")

# %%
for i in df.url[800:950]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df14 =pd.DataFrame({})
df14["Date"] = date1
df14["Author"] = author1
df14["Vertical"] = vertical1
df14["Headline"] = headline1
df14["Description"] = description1
df14.to_csv("news14.csv")

# %%
for i in df.url[950:1100]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df15 =pd.DataFrame({})
df15["Date"] = date1
df15["Author"] = author1
df15["Vertical"] = vertical1
df15["Headline"] = headline1
df15["Description"] = description1
df15.to_csv("news15.csv")

# %%
for i in df.url[1100:1300]:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df16 =pd.DataFrame({})
df16["Date"] = date1
df16["Author"] = author1
df16["Vertical"] = vertical1
df16["Headline"] = headline1
df16["Description"] = description1
df16.to_csv("news16.csv")

# %%
for i in df.url:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        a = driver.find_element_by_xpath("//div[@class='as_byline']/div[3]|//div[@class='yYIu- byline']/span")
        date1.append(a.text)
        
    except NoSuchElementException:
        date1.append(' ')
        
    try:
        b = driver.find_element_by_xpath("//div[@class='as_byline']/div[2]/a|//div[@class='yYIu- byline']/a|/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        author1.append(b.text)
        
    except NoSuchElementException:
        author1.append(' ')
            
    try:
        c = driver.find_element_by_xpath("/html/body/div/div/div/div/ol/li[2]/a/span|/html/body/div[2]/div/div[3]/div[3]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span|/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        vertical1.append(c.text)  
    except NoSuchElementException:
        vertical1.append(' ')
        
    try:
        d = driver.find_element_by_xpath("//h1[@class='_1Y-96']/span|//div[@class='as_heading']/h1")
        headline1.append(d.text) 
            
    except NoSuchElementException:
        headline1.append(' ')
    
    try:
        e = driver.find_element_by_xpath("//div[@class='Normal']|//div[@class='fewcent-80066375']/div|/html/body/div[2]/div/div[3]/div[4]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]|//div[@class='_3YYSt clearfix']|//div[@class='ga-headlines']")
        description1.append(e.text) 
    except NoSuchElementException:
        description1.append(' ')

# %%
df17 =pd.DataFrame({})
df17["Date"] = date1
df17["Author"] = author1
df17["Vertical"] = vertical1
df17["Headline"] = headline1
df17["Description"] = description1
df17.to_csv("news17.csv")

# %%
df1 = pd.read_csv("news 1.csv")
df1a= pd.read_csv("news1a.csv")
df2 = pd.read_csv("news2.csv")
df3 = pd.read_csv("news3.csv")
df4 = pd.read_csv("news4.csv")
df5 = pd.read_csv("news5.csv")
df6 = pd.read_csv("news6.csv")
df7 = pd.read_csv("news7.csv")
df8 = pd.read_csv("news8.csv")
df9 = pd.read_csv("news9.csv")
df10 = pd.read_csv("news10.csv")
df11 = pd.read_csv("news11.csv")
df12 = pd.read_csv("news12.csv")
df13 = pd.read_csv("news13.csv")
df14 = pd.read_csv("news14.csv")
df15 = pd.read_csv("news15.csv")
df16 = pd.read_csv("news16.csv")
df17 = pd.read_csv("news17.csv")
df = pd.concat([df1,df1a,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17],axis = 0)
df
# Out:
#      Unnamed: 0                              Date               Author  \
# 0             0   Created: Jan 1, 2021, 00:00 IST        Thinkal Menon
# 1             1
# 2             2   Created: Jan 3, 2021, 00:00 IST      Sunayana Suresh
# 3             3            Jan 4, 2021, 00:00 IST         Vinay Lokesh
# 4             4   Created: Jan 5, 2021, 00:00 IST         Vinay Lokesh
# ..          ...                               ...                  ...
# 305         305  Updated: Jan 27, 2021, 08:32 IST
# 306         306           Jan 28, 2021, 04:19 IST        Mohammad Anab
# 307         307  Updated: Jan 29, 2021, 11:25 IST
# 308         308           Jan 30, 2021, 04:27 IST
# 309         309  Updated: Jan 31, 2021, 15:55 IST  Chaitanya Marpakwar
#
#           Vertical                                           Headline  \
# 0    Entertainment                 Bharath, Janani in a romance drama
# 1    Entertainment  Mahesh Babu's heartfelt wishes for fans wishin...
# ...

# %%
df.to_csv("THE TIME OF INDIA_JAN_2021.csv")

# %%
driver.close()
