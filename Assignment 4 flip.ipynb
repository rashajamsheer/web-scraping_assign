# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException,ElementNotInteractableException
import requests
import re

# %% [raw]
# 1) Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver = webdriver.Chrome(r'C:\Users\USER\Downloads\chromedriver_win32 (3)\chromedriver.exe')
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/'
driver.get(url)

# %%
driver.find_element_by_xpath('//*[@id="noarticletext"]/tbody/tr/td/ul/li[2]/span/a/i').click()

# %%
driver.find_element_by_xpath("//span[@class='searchmatch']").click()

# %%
rank=[]
e = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tr/td[1]")
for i in e:
    rank.append(i.text)

# %%
name2 =[]
a = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tr/td[2]")
for i in a:                
    name2.append(i.text)

# %%
artist2=[]
b = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tr/td[3]")
for i in b:                      
    artist2.append(i.text)

# %%
date=[]
b = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tr/td[5]")
for i in b:                      
    date.append(i.text)

# %%
views=[]
b = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tr/td[4]")
for i in b:                      
    views.append(i.text)

# %%
df = pd.DataFrame({})
df["Rank"] = rank[0:30]
df["Name"] = name2[0:30]
df["Artist"] = artist2[0:30]
df["Upload date"] = date[0:30]
df["Views"] = views[0:30]
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                     "Axel F"[34]
# 14  15.                                      "Sugar"[35]
# ...

# %%
driver.close()

# %% [raw]
# 2. Scrape the details teamIndia’sinternationalfixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1stODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver = webdriver.Chrome(r'C:\Users\USER\Downloads\chromedriver_win32 (3)\chromedriver.exe')
url = 'https://www.bcci.tv/'
driver.get(url)

# %%
dropdown = driver.find_element_by_xpath('//*[@id="navigation"]/ul[1]/li[2]/a')
dropdown.click()

# %%
match=[]
place=[]
date=[]
time=[]

# %%
pl = driver.find_elements_by_xpath('//*[@id="match-card"]/div[3]/div/span[3]')
for d in pl:
    place.append(d.text)

# %%
place
# Out:
# ['London']

# %%
d = driver.find_elements_by_xpath('//*[@id="match-card"]/div[1]/div/div[2]')
for i in d:
    time.append(i.text)
time
# Out:
# ['3:30 PM IST']

# %%
p = driver.find_elements_by_xpath('//*[@id="match-card"]/div[1]/h5')
for d in p:
    match.append(d.text)
match
# Out:
# ['ICC WORLD TEST CHAMPIONSHIP FINAL 2023']

# %%
d = driver.find_elements_by_xpath("//div[@class='match-dates ng-binding']")
for i in d:
    date.append(i.text)
date
# Out:
# ['7 JUN 2023']

# %%
df = pd.DataFrame({})
df["Match"] = match
df["Place"] = place
df["Date"] = date
df["Time"] = time
df
# Out:
#                                     Match   Place        Date         Time
# 0  ICC WORLD TEST CHAMPIONSHIP FINAL 2023  London  7 JUN 2023  3:30 PM IST

# %%
driver.close()

# %% [raw]
# 3. Scrape the details of State-wise GDP ofIndia fromstatisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver = webdriver.Chrome(r'C:\Users\USER\Downloads\chromedriver_win32 (3)\chromedriver.exe')
url = 'http://statisticstimes.com/'
driver.get(url)

# %%
driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button').click()

# %%
driver.get('http://statisticstimes.com/economy/india-statistics.php')

# %%
driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[2]/ul/li[1]/a").click()

# %%
rank = []
state = []
price1 = []
price2 = []
Share = []
GDP = []

# %%
r = driver.find_elements_by_xpath("//td[@class='data1']")
for d in r :
    rank.append(d.text)
q = driver.find_elements_by_xpath("//td[@class='name']")
for d in q :
    state.append(d.text)
    
p = driver.find_elements_by_xpath('//tr[@role="row"]/td[3]')  
for d in p :
    price1.append(d.text)
    
s = driver.find_elements_by_xpath("//td[@class='data sorting_1']")
for d in s :
    price2.append(d.text)
    
t = driver.find_elements_by_xpath("//tr[@role='row']/td[5]")
for d in t :
    Share.append(d.text)
    
u = driver.find_elements_by_xpath("//tr[@role='row']/td[6]")   
for d in u :
    GDP.append(d.text)

# %%
df = pd.DataFrame({})
df["Rank"] = rank[0:33]
df["State"] = state[0:33]
df["GSDP at current price (19-20)"] = price1[0:33]
df["GSDP at current price (18-19)"] = price2[0:33]
df["Share(18-19)"] = Share[0:33]
df["GDP($ billion)"] = GDP[0:33]
df
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# 5     6                West Bengal                     1,253,832
# 6     7                  Rajasthan                     1,020,989
# 7     8             Andhra Pradesh                       972,782
# 8     9                  Telangana                       969,604
# 9    10             Madhya Pradesh                       906,672
# 10   11                     Kerala                             -
# 11   12                      Delhi                       856,112
# 12   13                    Haryana                       831,610
# ...

# %%
driver.close()

# %% [raw]
# 4. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code

# %%
driver = webdriver.Chrome(r'C:\Users\USER\Downloads\chromedriver_win32 (3)\chromedriver.exe')
url = 'https://github.com/'
driver.get(url)

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button').click()

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a').click()

# %%
repository=[]
description =[]
contributor = []
language_used =[]

# %%
url=[]
for i in driver.find_elements_by_xpath("//h2[@class='h3 lh-condensed']/a"):
    url.append(i.get_attribute("href"))

# %%
for i in url:
    driver.get(i)
    
    
    
    try:
        c = driver.find_element_by_xpath('//*[@id="readme"]/div[2]/article/h1')
        repository.append(c.text)
    except NoSuchElementException:
        repository.append('-')

    
    
    language = []     
    languages = driver.find_elements_by_xpath("//li[@class='d-inline']//a//span[1]")
    if languages:
        for i in languages:
            language.append(i.text)
    else:
        language.append('no language used')
    language_used.append(language)
    
    
    
    
    try:
        c = driver.find_element_by_xpath("//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        contributor.append(c.text)
    except NoSuchElementException:
        contributor.append('-')



    try:
        k = driver.find_element_by_xpath('//*[@id="repo-content-pjax-container"]/div/div/div[2]/div[2]/div/div[1]/div/p')
        description.append(k.text)
    except NoSuchElementException:
        description.append('-')

# %%
df = pd.DataFrame({"Repository":repository,"Description":description,"Contributors count":contributor,"Language_used":language_used})
df
# Out:
#                                            Repository  \
# 0                  GPT4free - use ChatGPT, for free!!
# 1                                                 Rye
# 2                                                   -
# 3                    Agent-LLM (Large Language Model)
# 4   Chart-GPT - text to beautiful charts within se...
# 5                                           dndserver
# 6                                             AI 法律助手
# 7                                          PentestGPT
# 8                                                   -
# 9                                                   -
# 10       Computer Science courses with video lectures
# 11                                                  -
# 12                                          Databerry
# 13                                                  -
# 14                                             🐶 Bark
# 15                                      ChatGPT Clone
# ...

# %%
driver.close()

# %% [raw]
# 5. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver = webdriver.Chrome(r'C:\Users\USER\Downloads\chromedriver_win32 (3)\chromedriver.exe')
url = 'https://www.billboard.com/'
driver.get(url)

# %%
driver.find_element_by_xpath('/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a').click()

# %%
driver.find_element_by_xpath('/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a').click()

# %%
Song = []
artist = []
wk_rank=[]
pk_rank=[]
wks=[]

# %%
a = driver.find_elements_by_xpath('//*[@id="title-of-a-story"]')
for i in a :
    Song.append(i.text)

b = driver.find_elements_by_xpath('//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]//li[4]/ul/li[1]/span')
for i in b :
    artist.append(i.text)   
    
c = driver.find_elements_by_xpath('//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]//li[4]/ul/li[4]/span')
for i in c :
    wk_rank.append(i.text)
        
d = driver.find_elements_by_xpath('//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]//li[5]/span')
for i in d :
    pk_rank.append(i.text)
    
e = driver.find_elements_by_xpath('//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]//li[6]/span')
for i in e :
    wks.append(i.text)

# %%
df = pd.DataFrame({})
df["Song name"] = Song[6:406:4]
df["Artist name"] = artist[1:]
df["Last week rank"] = wk_rank[1:]
df["Peak rank"] = pk_rank[1::2]
df["Weeks on board"] = wks[1:]
df
# Out:
#             Song name                              Artist name Last week rank  \
# 0           Kill Bill                                      SZA              4
# 1          Last Night                            Morgan Wallen              1
# 2             Flowers                              Miley Cyrus              3
# 3      Princess Diana                  Ice Spice & Nicki Minaj              -
# 4     Ella Baila Sola              Eslabon Armado X Peso Pluma             10
# ..                ...                                      ...            ...
# 95        Memory Lane                             Old Dominion             96
# 96         Love Again                            The Kid LAROI             88
# 97         '98 Braves                            Morgan Wallen            100
# 98          Di Que Si  Grupo Marca Registrada X Grupo Frontera              -
# 99  It Matters To Her                          Scotty McCreery              -
#
#    Peak rank Weeks on board
# ...

# %%
driver.close()

# %% [raw]
# 6. Scrape the details of Highest sellingnovels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver = webdriver.Chrome(r'C:\Users\USER\Downloads\chromedriver_win32 (3)\chromedriver.exe')
url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)

# %%
title = []
author = []
volume_sale = []
publisher = []
genre = []

# %%
a = driver.find_elements_by_xpath("//table[@class='in-article sortable']//td[2]")
for d in a :
    title.append(d.text)
    
b = driver.find_elements_by_xpath("//table[@class='in-article sortable']//td[3]")
for d in b :
    author.append(d.text)
    
c = driver.find_elements_by_xpath("//table[@class='in-article sortable']//td[4]")
for d in c :
    volume_sale.append(d.text)
    
d = driver.find_elements_by_xpath("//table[@class='in-article sortable']//td[5]")
for i in d :
    publisher.append(i.text)
    
e = driver.find_elements_by_xpath("//table[@class='in-article sortable']//td[6]")
for d in e :
    genre.append(d.text)

# %%
df = pd.DataFrame({})
df["Book name"] = title
df["Author name"] = author
df["Volumes sold"] = volume_sale
df["Publisher"] = publisher
df["Genre"] = genre
df
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [raw]
# 7. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver = webdriver.Chrome(r'C:\Users\USER\Downloads\chromedriver_win32 (3)\chromedriver.exe')
url = 'https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
name =[]
year=[]
genre=[]
time = []
rating = []
vote = []

# %%
a = driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
for d in a :
    name.append(d.text)
    
b = driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")
for d in b :
    year.append(d.text)
    
c = driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[5]")
for d in c :
    genre.append(d.text)
    
d = driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[3]")
for i in d :
    time.append(i.text)
    
e = driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]")
for i in e :
    rating.append(i.text)
    
f = driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[2]")
for i in f :
    vote.append(i.text)

# %%
df = pd.DataFrame({})
df["Name"] = name
df["Year span"] = year
df["Genre"] = genre
df["Run time"] = time
df["Ratings"] = rating
df["Votes"] = vote[1:200:2]
df
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2024)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  2,153,759
# ...

# %%
driver.close()

# %% [raw]
# 8. Details of Datasetsfrom UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
driver = webdriver.Chrome(r'C:\Users\USER\Downloads\chromedriver_win32 (3)\chromedriver.exe')
url = 'https://archive.ics.uci.edu/ml/index.php'
driver.get(url)

# %%
driver.find_element_by_xpath("//span[@class='whitetext']//b").click()

# %%
name =[]
types= []
task = []
atribute=[]
instance =[]
no_atri=[]
year=[]

# %%
a = driver.find_elements_by_xpath("//p[@class='normal']/b/a")
for i in a:
    name.append(i.text)
    
b = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p')
for i in b:
    types.append(i.text)
    
b = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p')
for i in b:
    task.append(i.text)
    
b = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p')
for i in b:
    atribute.append(i.text)
    
b = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p')
for i in b:
    instance.append(i.text)
    
b = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p')
for i in b:
    no_atri.append(i.text)
    
b = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p')
for i in b:
    year.append(i.text)

# %%
print(len(name),len(types),len(task),len(atribute),len(instance),len(no_atri),len(year))
# Out:
# 622 623 623 623 623 623 623

# %%
df = pd.DataFrame({"Dataset name":name,"Data type":types[1:],"Task":task[1:],"Attribute type":atribute[1:],"No of instances":instance[1:],"No of attribute":no_atri[1:],"Year":year[1:]})
df
# Out:
#                                           Dataset name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %%
driver.close()

# %% [raw]
# 9.Scrape the details of Data science recruiters Url = https://www.naukri.com/hr-recruiters-consultants
# You have to find the following details:
# A) Name
# B) Designation
# C)Company
# D)Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
driver = webdriver.Chrome(r'C:\Users\USER\Downloads\chromedriver_win32 (3)\chromedriver.exe')
url = 'https://www.naukri.com/hr-recruiters-consultants'
driver.get(url)

# %%
sr = driver.find_element_by_xpath("//div[@class='inpWrap']/input")
sr.clear()
sr.send_keys("Data science")

# %%
driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()

# %%
name = []
designation=[]
company = []
location = []
hire = []

# %%
a = driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
for i in a :
    name.append(i.text)
    
b = driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
for i in b :
    designation.append(i.text)
    
c = driver.find_elements_by_xpath("//p[@class='highlightable']/a[2]")
for i in c :
    company.append(i.text)
    
e = driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
for i in e:
    hire.append(i.text)

# %%
url=[]
for i in driver.find_elements_by_xpath("//p[@class='highlightable']/a"):
    url.append(i.get_attribute("href"))

# %%
for i in url:
    driver.get(i)
    
    try:
        d = driver.find_element_by_xpath("//div[@class ='rFrame fl infoWrapper']/div[5]/a")
        location.append(d.text)
    except NoSuchElementException:
        location.append("-")

# %%
print(len(name),len(designation),len(company),len(hire),len(location))
# Out:
# 50 50 50 50 100

# %%
df = pd.DataFrame({})
df["Name"] = name
df["Designation"] = designation
df["Company"]= company
df["Skills they hire for"] = hire
df["Location"] = location[0:100:2]
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                                 Priyanka Akiri
# 14                                   Kapil Devang
# 15                             Mahesh Babu Channa
# 16                             Vaishnavi Kudalkar
# 17                                Sakshi Chhikara
# ...

# %%
driver.close()
