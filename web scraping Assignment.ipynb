# %%
#import libraries
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Questione no: 1

# %%
page = requests.get("https://en.wikipedia.org/wiki/Main_Page")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
header= soup.find_all("h2",class_="mp-h2")
header
# Out:
# [<h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>,
#  <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>,
#  <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>,
#  <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>,
#  <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>,
#  <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>,
#  <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>,
# ...

# %%
header_tags=[]
for i in header:
    header_tags.append(i.text)
header_tags
# Out:
# ["From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']

# %%
import pandas as pd
header_1= pd.DataFrame({})
header_1["Header"]=header_tags

# %%
header_1
# Out:
#                           Header
# 0  From today's featured article
# 1               Did you know ...
# 2                    In the news
# 3                    On this day
# 4       Today's featured picture
# 5       Other areas of Wikipedia
# 6    Wikipedia's sister projects
# 7            Wikipedia languages

# %% [markdown]
# # Questione no:2

# %%
page = requests.get("https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>IMDb "Top 100"
# (Sorted by IMDb Rating Descending) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
# ...

# %%
names = soup.find_all("h3",class_="lister-item-header")
names
# Out:
# [<h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt0111161/">The Shawshank Redemption</a>
#  <span class="lister-item-year text-muted unbold">(1994)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">2.</span>
#  <a href="/title/tt0068646/">The Godfather</a>
#  <span class="lister-item-year text-muted unbold">(1972)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">3.</span>
#  <a href="/title/tt0468569/">The Dark Knight</a>
#  <span class="lister-item-year text-muted unbold">(2008)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">4.</span>
#  <a href="/title/tt0071562/">The Godfather: Part II</a>
#  <span class="lister-item-year text-muted unbold">(1974)</span>
#  </h3>,
#  <h3 class="lister-item-header">
# ...

# %%
movie_names=[]
for i in names:
    movie_names.append(i.text.replace('\n',''))
movie_names
# Out:
# ['1.The Shawshank Redemption(1994)',
#  '2.The Godfather(1972)',
#  '3.The Dark Knight(2008)',
#  '4.The Godfather: Part II(1974)',
#  '5.12 Angry Men(1957)',
#  '6.The Lord of the Rings: The Return of the King(2003)',
#  '7.Pulp Fiction(1994)',
#  "8.Schindler's List(1993)",
#  '9.Inception(2010)',
#  '10.Fight Club(1999)',
#  '11.The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '12.Forrest Gump(1994)',
#  '13.Il buono, il brutto, il cattivo(1966)',
#  '14.The Lord of the Rings: The Two Towers(2002)',
#  '15.The Matrix(1999)',
#  '16.Goodfellas(1990)',
#  '17.Star Wars: Episode V - The Empire Strikes Back(1980)',
#  "18.One Flew Over the Cuckoo's Nest(1975)",
#  '19.Gisaengchung(2019)',
#  '20.Interstellar(2014)',
#  '21.Cidade de Deus(2002)',
#  '22.Sen to Chihiro no kamikakushi(2001)',
#  '23.Saving Private Ryan(1998)',
#  '24.The Green Mile(1999)',
#  '25.La vita è bella(1997)',
#  '26.Se7en(1995)',
#  '27.The Silence of the Lambs(1991)',
#  '28.Star Wars(1977)',
# ...

# %%
IMDb_rating = soup.find_all("div",class_="inline-block ratings-imdb-rating")
IMDb_rating
# Out:
# [<div class="inline-block ratings-imdb-rating" data-value="9.3" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.3</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9.2" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.2</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.0</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.0</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.0</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="8.9" name="ir">
# ...

# %%
IMDb_ratings=[]
for i in IMDb_rating:
    IMDb_ratings.append(i.text.replace('\n',''))
IMDb_ratings
# Out:
# ['9.3',
#  '9.2',
#  '9.0',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5']

# %%
yr_release=soup.find_all("span",class_="lister-item-year text-muted unbold")
yr_release
# Out:
# [<span class="lister-item-year text-muted unbold">(1994)</span>,
#  <span class="lister-item-year text-muted unbold">(1972)</span>,
#  <span class="lister-item-year text-muted unbold">(2008)</span>,
#  <span class="lister-item-year text-muted unbold">(1974)</span>,
#  <span class="lister-item-year text-muted unbold">(1957)</span>,
#  <span class="lister-item-year text-muted unbold">(2003)</span>,
#  <span class="lister-item-year text-muted unbold">(1994)</span>,
#  <span class="lister-item-year text-muted unbold">(1993)</span>,
#  <span class="lister-item-year text-muted unbold">(2010)</span>,
#  <span class="lister-item-year text-muted unbold">(1999)</span>,
#  <span class="lister-item-year text-muted unbold">(2001)</span>,
#  <span class="lister-item-year text-muted unbold">(1994)</span>,
#  <span class="lister-item-year text-muted unbold">(1966)</span>,
#  <span class="lister-item-year text-muted unbold">(2002)</span>,
# ...

# %%
yrs_release=[]
for i in yr_release:
    yrs_release.append(i.text.replace('\n',''))
yrs_release
# Out:
# ['(1994)',
#  '(1972)',
#  '(2008)',
#  '(1974)',
#  '(1957)',
#  '(2003)',
#  '(1994)',
#  '(1993)',
#  '(2010)',
#  '(1999)',
#  '(2001)',
#  '(1994)',
#  '(1966)',
#  '(2002)',
#  '(1999)',
#  '(1990)',
#  '(1980)',
#  '(1975)',
#  '(2019)',
#  '(2014)',
#  '(2002)',
#  '(2001)',
#  '(1998)',
#  '(1999)',
#  '(1997)',
#  '(1995)',
#  '(1991)',
#  '(1977)',
#  '(1962)',
#  '(1954)',
#  '(1946)',
#  '(2020)',
#  '(2014)',
#  '(2011)',
#  '(2006)',
#  '(2006)',
#  '(2002)',
#  '(2000)',
#  '(1998)',
#  '(1995)',
#  '(1994)',
#  '(1994)',
#  '(1991)',
#  '(1988)',
#  '(1988)',
#  '(1985)',
#  '(1968)',
#  '(1960)',
#  '(1942)',
#  '(1936)']

# %%
IMDb=pd.DataFrame({})
IMDb["Movie Names"]=movie_names
IMDb["Ratings"]=IMDb_ratings
IMDb["Year of Release"]=yrs_release

# %%
IMDb
# Out:
#                                           Movie Names Ratings Year of Release
# 0                    1.The Shawshank Redemption(1994)     9.3          (1994)
# 1                               2.The Godfather(1972)     9.2          (1972)
# 2                             3.The Dark Knight(2008)     9.0          (2008)
# 3                      4.The Godfather: Part II(1974)     9.0          (1974)
# 4                                5.12 Angry Men(1957)     9.0          (1957)
# 5   6.The Lord of the Rings: The Return of the Kin...     8.9          (2003)
# 6                                7.Pulp Fiction(1994)     8.9          (1994)
# 7                            8.Schindler's List(1993)     8.9          (1993)
# 8                                   9.Inception(2010)     8.8          (2010)
# 9                                 10.Fight Club(1999)     8.8          (1999)
# 10  11.The Lord of the Rings: The Fellowship of th...     8.8          (2001)
# ...

# %% [markdown]
# saving the file as csv

# %%
IMDb.to_csv('imdb.csv',index=False)

# %%
df = pd.read_csv('imdb.csv')
df
# Out:
#                                           Movie Names  Ratings Year of Release
# 0                    1.The Shawshank Redemption(1994)      9.3          (1994)
# 1                               2.The Godfather(1972)      9.2          (1972)
# 2                             3.The Dark Knight(2008)      9.0          (2008)
# 3                      4.The Godfather: Part II(1974)      9.0          (1974)
# 4                                5.12 Angry Men(1957)      9.0          (1957)
# 5   6.The Lord of the Rings: The Return of the Kin...      8.9          (2003)
# 6                                7.Pulp Fiction(1994)      8.9          (1994)
# 7                            8.Schindler's List(1993)      8.9          (1993)
# 8                                   9.Inception(2010)      8.8          (2010)
# 9                                 10.Fight Club(1999)      8.8          (1999)
# 10  11.The Lord of the Rings: The Fellowship of th...      8.8          (2001)
# ...

# %% [markdown]
# # Questione no:4

# %%
page = requests.get("https://bookpage.com/reviews")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Book Reviews | BookPage</title>
# <meta content="Book recommendations of the best new books by genre and more." name="description"/>
# <meta content="book reviews, books and literature, writing and writers" name="keywords"/>
# <link href="https://bookpage.com/reviews" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Book Reviews" property="og:title"/>
# <meta content="Book recommendations of the best new books by genre and more." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://bookpage.com/reviews" property="og:url"/>
# <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@bookpage" name="twitter:site"/>
# <meta content="@bookpage" name="twitter:creator"/>
# ...

# %%
books=soup.find_all('h4',class_="italic",limit=5)
books
# Out:
# [<h4 class="italic">
#  <a href="/reviews/26173-joan-silber-secrets-happiness-fiction"> <span style="font-style:normal;">★ </span>Secrets of Happiness</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26194-stacey-swann-olympus-texas-fiction">Olympus, Texas</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26239-sarah-kuhn-from-little-tokyo-with-love-ya">From Little Tokyo, With Love</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26212-marc-hamer-seed-to-dust-nonfiction">Seed to Dust</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26330-emily-houghton-before-i-saw-you-romance">Before I Saw You</a>
#  </h4>]

# %%
books_name=[]
for i in books:
    books_name.append(i.text.replace('\n',''))
books_name
# Out:
# [' ★ Secrets of Happiness',
#  'Olympus, Texas',
#  'From Little Tokyo, With Love',
#  'Seed to Dust',
#  'Before I Saw You']

# %%
author_nm=soup.find_all("p",class_="sans bold",limit=5)
author_nm
# Out:
# [<p class="sans bold">
#  Joan Silber
#  </p>,
#  <p class="sans bold">
#  Stacey Swann
#  </p>,
#  <p class="sans bold">
#  Sarah Kuhn
#  </p>,
#  <p class="sans bold">
#  Marc Hamer
#  </p>,
#  <p class="sans bold">
#  Emily Houghton
#  </p>]

# %%
author_name=[]
for i in author_nm:
    author_name.append(i.text.replace('\n',''))
author_name
# Out:
# ['Joan Silber', 'Stacey Swann', 'Sarah Kuhn', 'Marc Hamer', 'Emily Houghton']

# %%
new_genre=soup.find_all('p',class_="genre-links hidden-phone",limit=5)
new_genre
# Out:
# [<p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
#   /
#  <a href="/search?book_genre=family_drama">Family Drama</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
#   /
#  <a href="/search?book_genre=family_drama">Family Drama</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=ya">YA</a>
#   /
#  <a href="/search?book_genre=ya_fiction">YA Fiction</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
#  <a href="/search?book_genre=memoir">Memoir</a>
#   /
#  <a href="/search?book_genre=nature">Nature</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=romance">Romance</a>
#   /
#  <a href="/search?book_genre=contemporary_romance">Contemporary Romance</a>
#  </p>]

# %%
genre =[]
for i in new_genre:
    genre.append(i.text.replace('\n',''))
genre
# Out:
# ['Fiction / Family Drama',
#  'Fiction / Family Drama',
#  'YA / YA Fiction',
#  'Nonfiction / Memoir / Nature',
#  'Romance / Contemporary Romance']

# %%
Books=pd.DataFrame({})
Books["Name of The Book"]=books_name
Books["Author"]=author_name
Books["Genre"]=genre

# %%
Books
# Out:
#                Name of The Book          Author  \
# 0        ★ Secrets of Happiness     Joan Silber
# 1                Olympus, Texas    Stacey Swann
# 2  From Little Tokyo, With Love      Sarah Kuhn
# 3                  Seed to Dust      Marc Hamer
# 4              Before I Saw You  Emily Houghton
#
#                             Genre
# 0          Fiction / Family Drama
# 1          Fiction / Family Drama
# 2                 YA / YA Fiction
# 3    Nonfiction / Memoir / Nature
# 4  Romance / Contemporary Romance

# %% [markdown]
# # Question no:5

# %%
page = requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
team_name=soup.find_all("td",class_="table-body__cell rankings-table__team",limit=10)
team_name
# Out:
# [<td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo AUS"></span>
#  <span class="u-hide-phablet">Australia</span>
#  <span class="u-show-phablet">AUS</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="u-hide-phablet">India</span>
#  <span class="u-show-phablet">IND</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo ENG"></span>
#  <span class="u-hide-phablet">England</span>
#  <span class="u-show-phablet">ENG</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo SA"></span>
#  <span class="u-hide-phablet">South Africa</span>
#  <span class="u-show-phablet">SA</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo PAK"></span>
#  <span class="u-hide-phablet">Pakistan</span>
# ...

# %%
Team=[]
for i in team_name:
    Team.append(i.text.replace("\n",""))
Team
# Out:
# ['AustraliaAUS',
#  'IndiaIND',
#  'EnglandENG',
#  'South AfricaSA',
#  'PakistanPAK',
#  'BangladeshBAN',
#  'West IndiesWI',
#  'Sri LankaSL',
#  'AfghanistanAFG',
#  'NetherlandsNED']

# %%
matches=soup.find_all("td",class_="table-body__cell u-center-text",limit=20)
matches
# Out:
# [<td class="table-body__cell u-center-text">25</td>,
#  <td class="table-body__cell u-center-text">2,945</td>,
#  <td class="table-body__cell u-center-text">29</td>,
#  <td class="table-body__cell u-center-text">3,344</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">3,100</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,137</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,323</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,157</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,222</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">1,652</td>,
#  <td class="table-body__cell u-center-text">17</td>,
# ...

# %%
Match=[]
for i in range(0,len(matches),2):
    Match.append(matches[i].text.replace("\n",""))
Match
# Out:
# ['25', '29', '27', '20', '24', '24', '27', '21', '17', '2']

# %%
point = soup.find_all("td",class_="table-body__cell u-center-text",limit=20)
point
# Out:
# [<td class="table-body__cell u-center-text">25</td>,
#  <td class="table-body__cell u-center-text">2,945</td>,
#  <td class="table-body__cell u-center-text">29</td>,
#  <td class="table-body__cell u-center-text">3,344</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">3,100</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,137</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,323</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,157</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,222</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">1,652</td>,
#  <td class="table-body__cell u-center-text">17</td>,
# ...

# %%
Point=[]
for i in range(1,len(point),2):
    Point.append(point[i].text.replace("\n",""))
Point
# Out:
# ['2,945',
#  '3,344',
#  '3,100',
#  '2,137',
#  '2,323',
#  '2,157',
#  '2,222',
#  '1,652',
#  '1,054',
#  '99']

# %%
rate = soup.find_all("td",class_="table-body__cell u-text-right rating",limit=10)
rate
# Out:
# [<td class="table-body__cell u-text-right rating">118</td>,
#  <td class="table-body__cell u-text-right rating">115</td>,
#  <td class="table-body__cell u-text-right rating">115</td>,
#  <td class="table-body__cell u-text-right rating">107</td>,
#  <td class="table-body__cell u-text-right rating">97</td>,
#  <td class="table-body__cell u-text-right rating">90</td>,
#  <td class="table-body__cell u-text-right rating">82</td>,
#  <td class="table-body__cell u-text-right rating">79</td>,
#  <td class="table-body__cell u-text-right rating">62</td>,
#  <td class="table-body__cell u-text-right rating">50</td>]

# %%
Rating=[]
for i in rate:
    Rating.append(i.text.replace("\n",""))
Rating
# Out:
# ['118', '115', '115', '107', '97', '90', '82', '79', '62', '50']

# %%
import pandas as pd
top_ranking=pd.DataFrame({})
top_ranking["Team"]=Team
top_ranking["Match"]=Match
top_ranking["Point"]=Point

# %%
top_ranking
# Out:
#              Team Match  Point
# 0    AustraliaAUS    25  2,945
# 1        IndiaIND    29  3,344
# 2      EnglandENG    27  3,100
# 3  South AfricaSA    20  2,137
# 4     PakistanPAK    24  2,323
# 5   BangladeshBAN    24  2,157
# 6   West IndiesWI    27  2,222
# 7     Sri LankaSL    21  1,652
# 8  AfghanistanAFG    17  1,054
# 9  NetherlandsNED     2     99

# %% [markdown]
# # ii)

# %%
page = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC ODI Match Player Rankings International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC ODI Match Player Rankings International Cricket Council" property="og:title"/>
# ...

# %%
batsman = soup.find_all("td",class_="table-body__cell name",limit=10)
batsman
# Out:
# [<td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/164">Virat Kohli</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/107">Rohit Sharma</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/226">Ross Taylor</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/167">Aaron Finch</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/506">Jonny Bairstow</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/3801">Fakhar Zaman</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/24">Francois du Plessis</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/170">David Warner</a>
#  </td>,
#  <td class="table-body__cell name">
# ...

# %%
batsmans=[]
for i in batsman:
    batsmans.append(i.text.replace("\n",""))
batsmans
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'Fakhar Zaman',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope',
#  'Mujeeb Ur Rahman']

# %%
team = soup.find_all("td",class_="table-body__cell nationality-logo",limit=10)
team
# Out:
# [<td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="table-body__logo-text">IND</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="table-body__logo-text">IND</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo NZ"></span>
#  <span class="table-body__logo-text">NZ</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo AUS"></span>
#  <span class="table-body__logo-text">AUS</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo ENG"></span>
#  <span class="table-body__logo-text">ENG</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo PAK"></span>
#  <span class="table-body__logo-text">PAK</span>
#  </td>,
# ...

# %%
Team=[]
for i in team:
    Team.append(i.text.replace("\n",""))
Team
# Out:
# ['IND', 'IND', 'NZ', 'AUS', 'ENG', 'PAK', 'SA', 'AUS', 'WI', 'AFG']

# %%
rating=soup.find_all("td",class_="table-body__cell u-text-right rating",limit=10)
rating
# Out:
# [<td class="table-body__cell u-text-right rating">857</td>,
#  <td class="table-body__cell u-text-right rating">825</td>,
#  <td class="table-body__cell u-text-right rating">801</td>,
#  <td class="table-body__cell u-text-right rating">791</td>,
#  <td class="table-body__cell u-text-right rating">785</td>,
#  <td class="table-body__cell u-text-right rating">778</td>,
#  <td class="table-body__cell u-text-right rating">778</td>,
#  <td class="table-body__cell u-text-right rating">773</td>,
#  <td class="table-body__cell u-text-right rating">773</td>,
#  <td class="table-body__cell u-text-right rating">708</td>]

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.replace("\n",""))
Rating
# Out:
# ['857', '825', '801', '791', '785', '778', '778', '773', '773', '708']

# %%
import pandas as pd
Bats_Man=pd.DataFrame({})
Bats_Man["Name"]=batsmans
Bats_Man["Team"]=Team
Bats_Man["Rating"]=Rating

# %%
Bats_Man
# Out:
#                   Name Team Rating
# 0          Virat Kohli  IND    857
# 1         Rohit Sharma  IND    825
# 2          Ross Taylor   NZ    801
# 3          Aaron Finch  AUS    791
# 4       Jonny Bairstow  ENG    785
# 5         Fakhar Zaman  PAK    778
# 6  Francois du Plessis   SA    778
# 7         David Warner  AUS    773
# 8            Shai Hope   WI    773
# 9     Mujeeb Ur Rahman  AFG    708

# %% [markdown]
# # iii)

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC ODI Match Player Rankings International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC ODI Match Player Rankings International Cricket Council" property="og:title"/>
# ...

# %%
bowler =soup.find_all("td",class_="table-body__cell name")
bowler
# Out:
# [<td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/164">Virat Kohli</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/107">Rohit Sharma</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/226">Ross Taylor</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/167">Aaron Finch</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/506">Jonny Bairstow</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/3801">Fakhar Zaman</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/24">Francois du Plessis</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/170">David Warner</a>
#  </td>,
#  <td class="table-body__cell name">
# ...

# %%
Bowler=[]
for i in bowler:
    Bowler.append(i.text.replace("\n",""))
Bowler
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'Fakhar Zaman',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope',
#  'Mujeeb Ur Rahman',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Chris Woakes',
#  'Josh Hazlewood',
#  'Pat Cummins',
#  'Mohammad Amir',
#  'Ben Stokes',
#  'Mohammad Nabi',
#  'Chris Woakes',
#  'Rashid Khan',
#  'Mitchell Santner',
#  'Imad Wasim',
#  'Colin de Grandhomme',
#  'Ravindra Jadeja',
#  'Sean Williams',
#  'Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'Fakhar Zaman',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope',
#  'Mujeeb Ur Rahman',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Chris Woakes',
#  'Josh Hazlewood',
#  'Pat Cummins',
#  'Mohammad Amir',
#  'Ben Stokes',
#  'Mohammad Nabi',
#  'Chris Woakes',
#  'Rashid Khan',
#  'Mitchell Santner',
#  'Imad Wasim',
# ...

# %%
bw=Bowler[9:19]
bw
# Out:
# ['Mujeeb Ur Rahman',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Chris Woakes',
#  'Josh Hazlewood',
#  'Pat Cummins',
#  'Mohammad Amir',
#  'Ben Stokes']

# %%
team= soup.find_all("td",class_="table-body__cell nationality-logo")
team
# Out:
# [<td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="table-body__logo-text">IND</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="table-body__logo-text">IND</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo NZ"></span>
#  <span class="table-body__logo-text">NZ</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo AUS"></span>
#  <span class="table-body__logo-text">AUS</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo ENG"></span>
#  <span class="table-body__logo-text">ENG</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo PAK"></span>
#  <span class="table-body__logo-text">PAK</span>
#  </td>,
# ...

# %%
Team=[]
for i in team:
    Team.append(i.text.replace("\n",""))
Team
# Out:
# ['IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'ENG',
#  'PAK',
#  'SA',
#  'AUS',
#  'WI',
#  'AFG',
#  'NZ',
#  'IND',
#  'BAN',
#  'SA',
#  'ENG',
#  'AUS',
#  'AUS',
#  'PAK',
#  'ENG',
#  'AFG',
#  'ENG',
#  'AFG',
#  'NZ',
#  'PAK',
#  'NZ',
#  'IND',
#  'ZIM',
#  'IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'ENG',
#  'PAK',
#  'SA',
#  'AUS',
#  'WI',
#  'AFG',
#  'NZ',
#  'IND',
#  'BAN',
#  'SA',
#  'ENG',
#  'AUS',
#  'AUS',
#  'PAK',
#  'ENG',
#  'AFG',
#  'ENG',
#  'AFG',
#  'NZ',
#  'PAK',
#  'NZ',
#  'IND',
#  'ZIM']

# %%
tm=Team[9:19]
tm
# Out:
# ['AFG', 'NZ', 'IND', 'BAN', 'SA', 'ENG', 'AUS', 'AUS', 'PAK', 'ENG']

# %%
rating= soup.find_all("td",class_="table-body__cell u-text-right rating")
rating
# Out:
# [<td class="table-body__cell u-text-right rating">857</td>,
#  <td class="table-body__cell u-text-right rating">825</td>,
#  <td class="table-body__cell u-text-right rating">801</td>,
#  <td class="table-body__cell u-text-right rating">791</td>,
#  <td class="table-body__cell u-text-right rating">785</td>,
#  <td class="table-body__cell u-text-right rating">778</td>,
#  <td class="table-body__cell u-text-right rating">778</td>,
#  <td class="table-body__cell u-text-right rating">773</td>,
#  <td class="table-body__cell u-text-right rating">773</td>,
#  <td class="table-body__cell u-text-right rating">708</td>,
#  <td class="table-body__cell u-text-right rating">691</td>,
#  <td class="table-body__cell u-text-right rating">690</td>,
#  <td class="table-body__cell u-text-right rating">668</td>,
#  <td class="table-body__cell u-text-right rating">666</td>,
#  <td class="table-body__cell u-text-right rating">665</td>,
#  <td class="table-body__cell u-text-right rating">660</td>,
# ...

# %%
Rate=[]
for i in rating:
    Rate.append(i.text.replace("\n",""))
Rate
# Out:
# ['857',
#  '825',
#  '801',
#  '791',
#  '785',
#  '778',
#  '778',
#  '773',
#  '773',
#  '708',
#  '691',
#  '690',
#  '668',
#  '666',
#  '665',
#  '660',
#  '646',
#  '638',
#  '295',
#  '294',
#  '273',
#  '270',
#  '268',
#  '263',
#  '257',
#  '245',
#  '238',
#  '857',
#  '825',
#  '801',
#  '791',
#  '785',
#  '778',
#  '778',
#  '773',
#  '773',
#  '708',
#  '691',
#  '690',
#  '668',
#  '666',
#  '665',
#  '660',
#  '646',
#  '638',
#  '295',
#  '294',
#  '273',
#  '270',
#  '268',
#  '263',
#  '257',
#  '245',
#  '238']

# %%
rt=Rate[9:19]
rt
# Out:
# ['708', '691', '690', '668', '666', '665', '660', '646', '638', '295']

# %%
top_bowler=pd.DataFrame({})
top_bowler["Bowler"]=bw
top_bowler["Team"]=tm
top_bowler["Rate"]=rt

# %%
top_bowler
# Out:
#              Bowler Team Rate
# 0  Mujeeb Ur Rahman  AFG  708
# 1        Matt Henry   NZ  691
# 2    Jasprit Bumrah  IND  690
# 3      Mehedi Hasan  BAN  668
# 4     Kagiso Rabada   SA  666
# 5      Chris Woakes  ENG  665
# 6    Josh Hazlewood  AUS  660
# 7       Pat Cummins  AUS  646
# 8     Mohammad Amir  PAK  638
# 9        Ben Stokes  ENG  295

# %% [markdown]
# # Question no:6

# %% [markdown]
# # i)

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
w_team=soup.find_all("td",class_="table-body__cell rankings-table__team")
w_team
# Out:
# [<td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo SA"></span>
#  <span class="u-hide-phablet">South Africa</span>
#  <span class="u-show-phablet">SA</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo ENG"></span>
#  <span class="u-hide-phablet">England</span>
#  <span class="u-show-phablet">ENG</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="u-hide-phablet">India</span>
#  <span class="u-show-phablet">IND</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo NZ"></span>
#  <span class="u-hide-phablet">New Zealand</span>
#  <span class="u-show-phablet">NZ</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo WI"></span>
#  <span class="u-hide-phablet">West Indies</span>
# ...

# %%
Wteam=[]
for i in w_team:
    Wteam.append(i.text.replace("\n",""))
Wteam
# Out:
# ['South AfricaSA',
#  'EnglandENG',
#  'IndiaIND',
#  'New ZealandNZ',
#  'West IndiesWI',
#  'PakistanPAK',
#  'BangladeshBAN',
#  'Sri LankaSL',
#  'IrelandIRE']

# %%
match=soup.find_all("td",class_="table-body__cell u-center-text")
match
# Out:
# [<td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,828</td>,
#  <td class="table-body__cell u-center-text">17</td>,
#  <td class="table-body__cell u-center-text">1,993</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,226</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">1,947</td>,
#  <td class="table-body__cell u-center-text">12</td>,
#  <td class="table-body__cell u-center-text">1,025</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,101</td>,
#  <td class="table-body__cell u-center-text">5</td>,
#  <td class="table-body__cell u-center-text">306</td>,
#  <td class="table-body__cell u-center-text">11</td>,
#  <td class="table-body__cell u-center-text">519</td>,
#  <td class="table-body__cell u-center-text">2</td>,
# ...

# %%
Match=[]
for i in range(0,len(match),2):
    Match.append(match[i].text.replace("\n",""))
Match
# Out:
# ['24', '17', '20', '21', '12', '15', '5', '11', '2']

# %%
Point=[]
for i in range(1,len(match),2):
    Point.append(match[i].text.replace("\n",""))
Point
# Out:
# ['2,828', '1,993', '2,226', '1,947', '1,025', '1,101', '306', '519', '25']

# %%
rating=soup.find_all("td",class_="table-body__cell u-text-right rating")
rating
# Out:
# [<td class="table-body__cell u-text-right rating">118</td>,
#  <td class="table-body__cell u-text-right rating">117</td>,
#  <td class="table-body__cell u-text-right rating">111</td>,
#  <td class="table-body__cell u-text-right rating">93</td>,
#  <td class="table-body__cell u-text-right rating">85</td>,
#  <td class="table-body__cell u-text-right rating">73</td>,
#  <td class="table-body__cell u-text-right rating">61</td>,
#  <td class="table-body__cell u-text-right rating">47</td>,
#  <td class="table-body__cell u-text-right rating">13</td>]

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.replace("\n",''))
Rating
# Out:
# ['118', '117', '111', '93', '85', '73', '61', '47', '13']

# %%
Wteams=pd.DataFrame({})
Wteams["Team"]=Wteam
Wteams["Match"]=Match
Wteams["Point"]=Point
Wteams["Rating"]=Rating

# %%
Wteams
# Out:
#              Team Match  Point Rating
# 0  South AfricaSA    24  2,828    118
# 1      EnglandENG    17  1,993    117
# 2        IndiaIND    20  2,226    111
# 3   New ZealandNZ    21  1,947     93
# 4   West IndiesWI    12  1,025     85
# 5     PakistanPAK    15  1,101     73
# 6   BangladeshBAN     5    306     61
# 7     Sri LankaSL    11    519     47
# 8      IrelandIRE     2     25     13

# %% [markdown]
# # ii)

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi")

page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC ODI Match Player Rankings International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC ODI Match Player Rankings International Cricket Council" property="og:title"/>
# ...

# %%
name=soup.find_all("td",class_="table-body__cell name",limit=10)
name
# Out:
# [<td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/1785">Lizelle Lee</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/469">Meg Lanning</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/558">Mithali Raj</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/1800">Natalie Sciver</a>
#  </td>,
#  <td class="table-body__cell name">
# ...

# %%
Name=[]
for i in name:
    Name.append(i.text.replace("\n",""))
Name
# Out:
# ['Lizelle Lee',
#  'Alyssa Healy',
#  'Stafanie Taylor',
#  'Meg Lanning',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Mithali Raj',
#  'Natalie Sciver',
#  'Laura Wolvaardt',
#  'Megan Schutt']

# %%
team=soup.find_all("td",class_="table-body__cell nationality-logo",limit=10)
team
# Out:
# [<td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo SA"></span>
#  <span class="table-body__logo-text">SA</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo AUS"></span>
#  <span class="table-body__logo-text">AUS</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo WI"></span>
#  <span class="table-body__logo-text">WI</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo AUS"></span>
#  <span class="table-body__logo-text">AUS</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo NZ"></span>
#  <span class="table-body__logo-text">NZ</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="table-body__logo-text">IND</span>
#  </td>,
# ...

# %%
Team=[]
for i in team:
    Team.append(i.text.replace("\n",""))
Team
# Out:
# ['SA', 'AUS', 'WI', 'AUS', 'NZ', 'IND', 'IND', 'ENG', 'SA', 'AUS']

# %%
rating=soup.find_all("td",class_="table-body__cell u-text-right rating",limit=10)
rating
# Out:
# [<td class="table-body__cell u-text-right rating">758</td>,
#  <td class="table-body__cell u-text-right rating">756</td>,
#  <td class="table-body__cell u-text-right rating">746</td>,
#  <td class="table-body__cell u-text-right rating">723</td>,
#  <td class="table-body__cell u-text-right rating">715</td>,
#  <td class="table-body__cell u-text-right rating">710</td>,
#  <td class="table-body__cell u-text-right rating">709</td>,
#  <td class="table-body__cell u-text-right rating">685</td>,
#  <td class="table-body__cell u-text-right rating">683</td>,
#  <td class="table-body__cell u-text-right rating">762</td>]

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.replace("\n",""))
Rating
# Out:
# ['758', '756', '746', '723', '715', '710', '709', '685', '683', '762']

# %%
player=pd.DataFrame({})
player["Player"]=Name
player["Team"]=Team
player["Rating"]=Rating

# %%
player
# Out:
#               Player Team Rating
# 0        Lizelle Lee   SA    758
# 1       Alyssa Healy  AUS    756
# 2    Stafanie Taylor   WI    746
# 3        Meg Lanning  AUS    723
# 4  Amy Satterthwaite   NZ    715
# 5    Smriti Mandhana  IND    710
# 6        Mithali Raj  IND    709
# 7     Natalie Sciver  ENG    685
# 8    Laura Wolvaardt   SA    683
# 9       Megan Schutt  AUS    762

# %% [markdown]
# # iii)

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
player=soup.find_all("td",class_="table-body__cell name")
player
# Out:
# [<td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/1785">Lizelle Lee</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/469">Meg Lanning</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/558">Mithali Raj</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/1800">Natalie Sciver</a>
#  </td>,
#  <td class="table-body__cell name">
# ...

# %%
Player=[]
for i in player:
    Player.append(i.text.replace("\n",""))
Player
# Out:
# ['Lizelle Lee',
#  'Alyssa Healy',
#  'Stafanie Taylor',
#  'Meg Lanning',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Mithali Raj',
#  'Natalie Sciver',
#  'Laura Wolvaardt',
#  'Megan Schutt',
#  'Marizanne Kapp',
#  'Shabnim Ismail',
#  'Jhulan Goswami',
#  'Katherine Brunt',
#  'Poonam Yadav',
#  'Ayabonga Khaka',
#  'Ellyse Perry',
#  'Shikha Pandey',
#  'Ellyse Perry',
#  'Stafanie Taylor',
#  'Natalie Sciver',
#  'Deepti Sharma',
#  'Jess Jonassen',
#  'Ashleigh Gardner',
#  'Dane van Niekerk',
#  'Sophie Devine',
#  'Amelia Kerr']

# %%
pr=Player[18:27]
pr
# Out:
# ['Ellyse Perry',
#  'Stafanie Taylor',
#  'Natalie Sciver',
#  'Deepti Sharma',
#  'Jess Jonassen',
#  'Ashleigh Gardner',
#  'Dane van Niekerk',
#  'Sophie Devine',
#  'Amelia Kerr']

# %%
team=soup.find_all("span",class_="table-body__logo-text")
team
# Out:
# [<span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
# ...

# %%
Team=[]
for i in team:
    Team.append(i.text.replace("\n",""))
Team
# Out:
# ['SA',
#  'AUS',
#  'WI',
#  'AUS',
#  'NZ',
#  'IND',
#  'IND',
#  'ENG',
#  'SA',
#  'AUS',
#  'SA',
#  'SA',
#  'IND',
#  'ENG',
#  'IND',
#  'SA',
#  'AUS',
#  'IND',
#  'AUS',
#  'WI',
#  'ENG',
#  'IND',
#  'AUS',
#  'AUS',
#  'SA',
#  'NZ',
#  'NZ']

# %%
tm=Team[18:27]
tm
# Out:
# ['AUS', 'WI', 'ENG', 'IND', 'AUS', 'AUS', 'SA', 'NZ', 'NZ']

# %%
rating=soup.find_all("td",class_="table-body__cell rating",limit=9)
rating
# Out:
# [<td class="table-body__cell rating">418</td>,
#  <td class="table-body__cell rating">410</td>,
#  <td class="table-body__cell rating">349</td>,
#  <td class="table-body__cell rating">343</td>,
#  <td class="table-body__cell rating">307</td>,
#  <td class="table-body__cell rating">252</td>,
#  <td class="table-body__cell rating">243</td>,
#  <td class="table-body__cell rating">242</td>,
#  <td class="table-body__cell rating">236</td>]

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.replace("\n",""))
Rating
# Out:
# ['418', '410', '349', '343', '307', '252', '243', '242', '236']

# %%
all_rounder=pd.DataFrame({})
all_rounder["Player"]=pr
all_rounder["Team"]= tm
all_rounder["Rating"]=Rating

# %%
all_rounder
# Out:
#              Player Team Rating
# 0      Ellyse Perry  AUS    418
# 1   Stafanie Taylor   WI    410
# 2    Natalie Sciver  ENG    349
# 3     Deepti Sharma  IND    343
# 4     Jess Jonassen  AUS    307
# 5  Ashleigh Gardner  AUS    252
# 6  Dane van Niekerk   SA    243
# 7     Sophie Devine   NZ    242
# 8       Amelia Kerr   NZ    236

# %% [markdown]
# # Question no:7

# %%
page = requests.get("https://www.amazon.in/s?k=mobile+under+20000&crid=25XEG35PQHAWQ&sprefix=mobile+under+%2Caps%2C295&ref=nb_sb_ss_i_11_13")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:feature:aui-assets -->
# ...

# %%
phone=soup.find_all("span",class_="a-size-medium a-color-base a-text-normal",limit=11)
phone
# Out:
# [<span class="a-size-medium a-color-base a-text-normal">Redmi 9A (Nature Green, 2GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Oppo A31 (Mystery Black, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Oppo A31 (Fantasy White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Vivo Y91i (Fusion Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers</span>,
# ...

# %%
Mobile=[]
for i in phone:
    Mobile.append(i.text.replace("\n",""))
Mobile
# Out:
# ['Redmi 9A (Nature Green, 2GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor',
#  'Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor',
#  'Oppo A31 (Mystery Black, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#  'Oppo A31 (Fantasy White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Vivo Y91i (Fusion Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'OPPO A31 (Fantasy White, 4GB RAM, 64GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storage) - 48MP Quad Camera & Full HD+ Display',
#  'Redmi 9 Power (Mighty Black, 6GB RAM, 128GB Storage) - 6000mAh Battery |FHD+ Screen| 48MP Quad Camera | Snapdragon 662 Processor',
# ...

# %%
price=soup.find_all("span",class_="a-price-whole",limit=11)
price
# Out:
# [<span class="a-price-whole">19,990</span>,
#  <span class="a-price-whole">24,980</span>,
#  <span class="a-price-whole">14,999</span>,
#  <span class="a-price-whole">21,490</span>,
#  <span class="a-price-whole">6,799</span>,
#  <span class="a-price-whole">8,799</span>,
#  <span class="a-price-whole">11,990</span>,
#  <span class="a-price-whole">10,999</span>,
#  <span class="a-price-whole">11,990</span>,
#  <span class="a-price-whole">7,490</span>,
#  <span class="a-price-whole">10,990</span>]

# %%
Price=[]
for i in price:
    Price.append(i.text.replace("\n",""))
Price
# Out:
# ['19,990',
#  '24,980',
#  '14,999',
#  '21,490',
#  '6,799',
#  '8,799',
#  '11,990',
#  '10,999',
#  '11,990',
#  '7,490',
#  '10,990']

# %%
image=soup.find_all("img",class_="s-image",limit=11)
image
# Out:
# [<img alt="" class="s-image" height="44" src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/42eb2686-fe64-45ec-87ff-17f7f7c47036._CR0,0,500,500_SX50_._TTW_.jpg" width="44"/>,
#  <img alt="Vivo V11 (Starry Night Black)" class="s-image" data-image-index="0" data-image-latency="s-product-image" data-image-load="" data-image-source-density="1" onload="window.uet &amp;&amp; uet('cf')" src="https://m.media-amazon.com/images/I/51ldC3-JADL._AC_UL320_.jpg" srcset="https://m.media-amazon.com/images/I/51ldC3-JADL._AC_UL320_.jpg 1x, https://m.media-amazon.com/images/I/51ldC3-JADL._AC_UL480_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/51ldC3-JADL._AC_UL640_QL65_.jpg 2x, https://m.media-amazon.com/images/I/51ldC3-JADL._AC_UL800_QL65_.jpg 2.5x, https://m.media-amazon.com/images/I/51ldC3-JADL._AC_UL960_QL65_.jpg 3x"/>,
# ...

# %%
image_url=[]
for i in image:
    image_url.append(i.get("src"))
image_url
# Out:
# ['https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/42eb2686-fe64-45ec-87ff-17f7f7c47036._CR0,0,500,500_SX50_._TTW_.jpg',
#  'https://m.media-amazon.com/images/I/51ldC3-JADL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71FringFilL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71-Su4Wr0HL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61T9jicrIKL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71KCwNV6MuL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71yYaNztZ0L._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61IhTtJUXJL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/51ZoulFBPGL._AC_UY218_.jpg']

# %%
rating=soup.find_all("i",class_="a-icon a-icon-star-small a-star-small-4 aok-align-bottom",limit=11)
rating
# Out:
# [<i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.2 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.2 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.2 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.2 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.2 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.2 out of 5 stars</span></i>,
# ...

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.replace("\n",""))
Rating
# Out:
# ['4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
print(len(Mobile),len(image_url),len(Price),len(Rating))
# Out:
# 11 11 11 11

# %%
import pandas as pd
mobile=pd.DataFrame({})
mobile["Name"] = Mobile
mobile["URL"] = image_url
mobile["Price"] = Price
mobile["Rating"] = Rating

# %%
mobile
# Out:
#                                                  Name  \
# 0   Redmi 9A (Nature Green, 2GB Ram, 32GB Storage)...
# 1   Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 500...
# 2   Oppo A31 (Mystery Black, 6GB RAM, 128GB Storag...
# 3   Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage...
# 4   Oppo A31 (Fantasy White, 6GB RAM, 128GB Storag...
# 5   Vivo Y91i (Fusion Black, 2GB RAM, 32GB Storage...
# 6   OPPO A31 (Fantasy White, 4GB RAM, 64GB Storage...
# 7   Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storag...
# 8   Redmi 9 Power (Mighty Black, 6GB RAM, 128GB St...
# 9   Redmi 9A (Midnight Black, 3GB Ram, 32GB Storag...
# 10  Samsung Galaxy M31 (Space Black, 6GB RAM, 128G...
#
#                                                   URL   Price  \
# 0   https://images-eu.ssl-images-amazon.com/images...  19,990
# 1   https://m.media-amazon.com/images/I/51ldC3-JAD...  24,980
# 2   https://m.media-amazon.com/images/I/71FringFil...  14,999
# 3   https://m.media-amazon.com/images/I/71-Su4Wr0H...  21,490
# ...

# %% [markdown]
# # Questine no:8

# %%
page=requests.get("https://forecast.weather.gov/MapClick.php?lat=37.77493000000004&lon=-122.41941999999995#.YJQXZbUzZPY")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js">
# <head>
# <!-- Meta -->
# <meta content="width=device-width" name="viewport"/>
# <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/><title>National Weather Service</title><meta content="National Weather Service" name="DC.title"/><meta content="NOAA National Weather Service National Weather Service" name="DC.description"/><meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/><meta content="" name="DC.date.created" scheme="ISO8601"/><meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/><meta content="weather, National Weather Service" name="DC.keywords"/><meta content="NOAA's National Weather Service" name="DC.publisher"/><meta content="National Weather Service" name="DC.contributor"/><meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/><meta content="General" name="rating"/><meta content="index,follow" name="robots"/>
# <!-- Icons -->
# ...

# %%
period=soup.find_all("p",class_="period-name")
period
# Out:
# [<p class="period-name">Overnight<br/><br/></p>,
#  <p class="period-name">Saturday<br/><br/></p>,
#  <p class="period-name">Saturday<br/>Night</p>,
#  <p class="period-name">Sunday<br/><br/></p>,
#  <p class="period-name">Sunday<br/>Night</p>,
#  <p class="period-name">Monday<br/><br/></p>,
#  <p class="period-name">Monday<br/>Night</p>,
#  <p class="period-name">Tuesday<br/><br/></p>,
#  <p class="period-name">Tuesday<br/>Night</p>]

# %%
Period=[]
for i in period:
    Period.append(i.text.replace("\n",""))
Period
# Out:
# ['Overnight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday',
#  'SundayNight',
#  'Monday',
#  'MondayNight',
#  'Tuesday',
#  'TuesdayNight']

# %%
short_desc=soup.find_all("p",class_="short-desc")
short_desc
# Out:
# [<p class="short-desc">Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>]

# %%
Desc=[]
for i in short_desc:
    Desc.append(i.text.replace("\n",""))
Desc
# Out:
# ['Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Clear',
#  'Sunny',
#  'Clear',
#  'Sunny',
#  'Mostly Clear']

# %%
temp1=soup.find_all("li",class_="forecast-tombstone")
temp1
# Out:
# [<li class="forecast-tombstone">
#  <div class="tombstone-container">
#  <p class="period-name">Today<br/><br/></p>
#  <p><img alt="Today: Sunny, with a high near 77. Northwest wind 9 to 15 mph, with gusts as high as 29 mph. " class="forecast-icon" src="newimages/medium/skc.png" title="Today: Sunny, with a high near 77. Northwest wind 9 to 15 mph, with gusts as high as 29 mph. "/></p><p class="short-desc">Sunny</p><p class="temp temp-high">High: 77 °F</p></div></li>,
#  <li class="forecast-tombstone">
#  <div class="tombstone-container">
#  <p class="period-name">Tonight<br/><br/></p>
#  <p><img alt="Tonight: Clear, with a low around 53. West wind 6 to 14 mph, with gusts as high as 18 mph. " class="forecast-icon" src="newimages/medium/nskc.png" title="Tonight: Clear, with a low around 53. West wind 6 to 14 mph, with gusts as high as 18 mph. "/></p><p class="short-desc">Clear</p><p class="temp temp-low">Low: 53 °F</p></div></li>,
#  <li class="forecast-tombstone">
# ...

# %%
Temp1=[]
for i in temp1:
    Temp1.append(i.text.replace("\n",""))
Temp1
# Out:
# ['TodaySunnyHigh: 77 °F',
#  'TonightClearLow: 53 °F',
#  'SundaySunnyHigh: 71 °F',
#  'SundayNightClearLow: 53 °F',
#  'MondaySunnyHigh: 73 °F',
#  'MondayNightClearLow: 52 °F',
#  'TuesdaySunnyHigh: 72 °F',
#  'TuesdayNightMostly ClearLow: 51 °F',
#  'WednesdaySunnyHigh: 70 °F']

# %%
sanfran=pd.DataFrame({})
sanfran["Period"]=Period
sanfran["Short_desc"]=Desc
sanfran["Temperature"]=Temp1

# %%
sanfran
# Out:
#           Period    Short_desc                         Temperature
# 0      Overnight         Clear               TodaySunnyHigh: 77 °F
# 1       Saturday         Sunny              TonightClearLow: 53 °F
# 2  SaturdayNight  Mostly Clear              SundaySunnyHigh: 71 °F
# 3         Sunday         Sunny          SundayNightClearLow: 53 °F
# 4    SundayNight         Clear              MondaySunnyHigh: 73 °F
# 5         Monday         Sunny          MondayNightClearLow: 52 °F
# 6    MondayNight         Clear             TuesdaySunnyHigh: 72 °F
# 7        Tuesday         Sunny  TuesdayNightMostly ClearLow: 51 °F
# 8   TuesdayNight  Mostly Clear           WednesdaySunnyHigh: 70 °F
