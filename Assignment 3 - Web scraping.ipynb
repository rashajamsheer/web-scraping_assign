# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException,ElementNotInteractableException
import requests
import re

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = 'https://www.amazon.in/'
driver.get(url)

# %%
user_inp = input("Enter the product:")
# Out:
# Enter the product:watches

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")
search_bar.clear()
search_bar.send_keys(user_inp)
search_button = driver.find_element_by_id("nav-search-submit-button")
search_button.click()

# %%
url=[]
for i in range(0,3):
    for j in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):
        url.append(j.get_attribute("href"))
        
    driver.find_element_by_xpath("//li[@class='a-last']/a").click()
    time.sleep(4)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-5-f6ec397ae0d8> in <module>
#       4         url.append(j.get_attribute("href"))
#       5
# ----> 6     driver.find_element_by_xpath("//li[@class='a-last']/a").click()
#       7     time.sleep(4)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
# ...

# %%
url
# Out:
# ['https://www.amazon.in/Lorenz-Wallet-Wayfarer-Sunglasses-CM-1062SN-WL-BLK/dp/B07H7VD5XD/ref=sr_1_1?dchild=1&keywords=Watches&qid=1622711935&smid=A5J8YGZUIQBPS&sr=8-1',
#  'https://www.amazon.in/Fastrack-Reflex-Digital-Black-Watch-SWD90059PP05/dp/B07DQN5B3G/ref=sr_1_2?dchild=1&keywords=Watches&qid=1622711935&sr=8-2',
#  'https://www.amazon.in/Acnos-Stylist-Analog-Watch-Combo/dp/B07TY76N4F/ref=sr_1_3?dchild=1&keywords=Watches&qid=1622711935&sr=8-3',
#  'https://www.amazon.in/Acnos-Brand-Shockproof-Multi-Functional-Waterproof/dp/B08YP6S6HW/ref=sr_1_4?dchild=1&keywords=Watches&qid=1622711935&sr=8-4',
#  'https://www.amazon.in/Texton-Warranty-Pressure-Waterproof-Smartwatch/dp/B095HVCGTD/ref=sr_1_5?dchild=1&keywords=Watches&qid=1622711935&sr=8-5',
#  'https://www.amazon.in/Noise-Colorfit-Pro-Touch-Control/dp/B07YY1BY5B/ref=sr_1_6?dchild=1&keywords=Watches&qid=1622711935&sr=8-6',
# ...

# %%
len(url)
# Out:
# 144

# %%
Brand_Name=[]
Name_of_the_Product=[]
Rating=[]
No_of_Rating=[]
Return_Exchange=[]
Availability=[]

# %%
for i in url[7:151]:
    driver.get(i)
    time.sleep(3)
    
    
    try:
        j = driver.find_element_by_id("bylineInfo")
        Brand_Name.append(j.text)
    except NoSuchElementException:
        Brand_Name.append('-')
        
    try:
        k = driver.find_element_by_id("productTitle")
        Name_of_the_Product.append(k.text)
    except NoSuchElementException:
        Name_of_the_Product.append('-')
        
    try:
        l = driver.find_element_by_xpath("//span[@class ='a-size-base a-nowrap']/span")
        Rating.append(l.text)
    except NoSuchElementException:
        Rating.append('-')
        
    try:
        m = driver.find_element_by_xpath("//span[@class= 'a-size-base a-color-secondary']")
        No_of_Rating.append(m.text)
    except NoSuchElementException:
        No_of_Rating.append('-')
        
    try:
        o = driver.find_element_by_xpath("//a[@class='a-size-small a-link-normal a-text-normal']")
        Return_Exchange.append(o.text)
    except NoSuchElementException:
        Return_Exchange.append('-')
        
    try:
        q =driver.find_element_by_id("availability")
        Availability.append(q.text)
    except NoSuchElementException:
        Availability.append('-')

# %%
Brand_Name
# Out:
# ['Brand: A',
#  'Brand: A',
#  'Visit the EDDY HAGER Store',
#  'Brand: Generic',
#  'Visit the TIMEWEAR Store',
#  'Visit the SHOPTOSHOP Store',
#  'Brand: HEMT',
#  'Brand: Watch City',
#  'Visit the TIMEWEAR Store',
#  'Brand: Acnos',
#  'Visit the RUSTET Store',
#  'Visit the Decode Store',
#  'Visit the SWISSTYLE Store',
#  'Brand: Canbee',
#  'Visit the RUSTET Store',
#  'Brand: Sketchfab',
#  'Brand: Squaircle',
#  'Visit the Fastrack Store',
#  'Visit the Zesta Store',
#  'Visit the TIMEWEAR Store',
#  'Visit the LORENZ Store',
#  'Brand: Acnos',
#  'Brand: VILLS LAURRENS',
#  'Visit the MAGBOT Store',
#  'Visit the LORENZ Store',
#  'Visit the Watch Me Store',
#  'Visit the PIRASO Store',
#  'Brand: VILLS LAURRENS',
#  'Visit the ZEBRONICS Store',
#  'Visit the TIMEX Store',
#  'Visit the SKMEI Store',
#  'Visit the Sonata Store',
#  'Visit the SHOPTOSHOP Store',
#  'by\nGene Stone (Author)',
#  'Visit the RUSTET Store',
#  'Brand: Fastrack',
#  'Brand: TechKing',
# ...

# %%
Name_of_the_Product
# Out:
# ['Acnos Brand - A Full Black Stailess Steel Case with Uniq Time Presentation Analog Watch with FRE King Bracelet for Mens/Watch for Boys Pack of 2',
#  'Acnos Brand - A Full Black Stailess Steel Case with Uniq Time Presentation Analog Watch with FRE King Bracelet for Mens/Watch for Boys Pack of 2',
#  "EDDY HAGER Time Teacher - Analogue Men's Watch EH-226",
#  'Shoppers4u Bluetooth Wireless Smart Fitness Band for Boys/Men/Kids/Women | Sports Watch Compatible with Xiaomi, Oppo, Vivo Mobile Phone | Heart Rate and BP Monitor, Calories Counter',
#  'TIMEWEAR Analog Two Hands Slim Watch for Men',
#  'Shoptoshop SM3 Smart Band Fitness Tracker Watch Heart Rate with Activity Tracker Waterproof Body Functions Like Steps Counter, Calorie Counter, Heart Rate Monitor LED Touchscreen (Black)',
#  'HEMT Golden Dial Day & Display Analog Watch - HM-GSQ005-GLD-GLD',
#  "Watch City Sports Digital Men's Watch (Black Dial Green Colored Strap)",
# ...

# %%
Rating
# Out:
# ['4.2 out of 5',
#  '4.2 out of 5',
#  '3.9 out of 5',
#  '3 out of 5',
#  '3.9 out of 5',
#  '3.1 out of 5',
#  '5 out of 5',
#  '4.2 out of 5',
#  '3.7 out of 5',
#  '3.9 out of 5',
#  '3.5 out of 5',
#  '3.3 out of 5',
#  '3.5 out of 5',
#  '5 out of 5',
#  '3.2 out of 5',
#  '2.8 out of 5',
#  '4.1 out of 5',
#  '3.9 out of 5',
#  '3.4 out of 5',
#  '3.8 out of 5',
#  '4 out of 5',
#  '4.3 out of 5',
#  '3.4 out of 5',
#  '3.3 out of 5',
#  '3.9 out of 5',
#  '3.5 out of 5',
#  '3.9 out of 5',
#  '3.5 out of 5',
#  '4 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '4 out of 5',
#  '3.3 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '3.5 out of 5',
#  '3.7 out of 5',
#  '-',
#  '3.6 out of 5',
#  '3.6 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4 out of 5',
#  '3.3 out of 5',
#  '2 out of 5',
#  '4.1 out of 5',
#  '-',
#  '4.1 out of 5',
#  '3.7 out of 5',
#  '4.2 out of 5',
#  '3.5 out of 5',
#  '4 out of 5',
# ...

# %%
No_of_Rating
# Out:
# ['12 global ratings',
#  '12 global ratings',
#  '3,723 global ratings',
#  '',
#  '3,444 global ratings',
#  '',
#  '1 global rating',
#  '162 global ratings',
#  '1,722 global ratings',
#  '1,197 global ratings',
#  '42 global ratings',
#  '483 global ratings',
#  '1,940 global ratings',
#  '2 global ratings',
#  '14 global ratings',
#  '180 global ratings',
#  '68 global ratings',
#  '2,139 global ratings',
#  '187 global ratings',
#  '8,127 global ratings',
#  '5 global ratings',
#  '61 global ratings',
#  '2,781 global ratings',
#  '252 global ratings',
#  '1,053 global ratings',
#  '624 global ratings',
#  '167 global ratings',
#  '1,025 global ratings',
#  '793 global ratings',
#  '1,447 global ratings',
#  '626 global ratings',
#  '4,000 global ratings',
#  '',
#  'You Save: ₹ 1,096.00 (29%)',
#  '38 global ratings',
#  '',
#  '5 global ratings',
#  '133 global ratings',
#  '2,534 global ratings',
#  '-',
#  '8 global ratings',
#  '59 global ratings',
#  '5 global ratings',
# ...

# %%
Return_Exchange
# Out:
# ['1 Year Warranty',
#  '1 Year Warranty',
#  '10 Days Returns',
#  '10 days Replacement',
#  '10 Days Returns',
#  '10 days Replacement',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '10 Days Replacement',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '7 Days Replacement',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '7 Days Replacement',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 Days Returns',
#  '10 days Replacement',
#  '10 Days Replacement Only',
#  '10 Days Returns',
#  '10 Days Returns',
#  '7 Days Replacement Only',
#  '7 Days Replacement',
#  '10 Days Returns',
#  '-',
#  '10 Days Returns',
#  '24 Month Warranty',
#  '10 Days Returns',
# ...

# %%
Availability
# Out:
# ['',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock on June 7, 2021.\nOrder it now.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  '',
#  'Only 3 left in stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '',
#  'In stock.',
#  'In stock.',
#  'In stock on June 5, 2021.\nOrder it now.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
# ...

# %%
delivery=[]

# %%
for i in url[7:151]:
    driver.get(i)
    time.sleep(3)
    
    try:
        p =driver.find_element_by_id("ddmDeliveryMessage")
        delivery.append(p.text)
    except NoSuchElementException:
        delivery.append('-')

# %%
delivery
# Out:
# ['-',
#  'This item cannot be shipped to your selected delivery location. Please choose a different delivery location.',
#  'This item cannot be shipped to your selected delivery location. Please choose a different delivery location.',
#  'This item cannot be shipped to your selected delivery location. Please choose a different delivery location.',
#  'FREE delivery: Wednesday, June 9 Details',
#  'This item cannot be shipped to your selected delivery location. Please choose a different delivery location.',
#  'This item cannot be shipped to your selected delivery location. Please choose a different delivery location.',
#  'This item cannot be shipped to your selected delivery location. Please choose a different delivery location.',
#  'This item cannot be shipped to your selected delivery location. Please choose a different delivery location.',
#  'This item cannot be shipped to your selected delivery location. Please choose a different delivery location.',
# ...

# %%
Price=[]

# %%
for i in url[7:151]:
    driver.get(i)
    time.sleep(3)
    try:
        o = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[5]/div[1]/div[1]/div[2]/div[2]/div/div/div[1]/div[2]/div[1]/div/table/tbody/tr[2]/td[2]/span[1]')
        Price.append(o.text)
    except NoSuchElementException:
        Price.append('-')

# %%
Price
# Out:
# ['-',
#  '₹ 349.00',
#  '-',
#  '₹ 359.00',
#  '-',
#  '₹ 569.00',
#  '₹ 349.00',
#  '₹ 329.00',
#  '₹ 359.00',
#  '₹ 479.00',
#  '₹ 329.00',
#  '₹ 399.00',
#  '₹ 1,499.00',
#  '₹ 359.00',
#  '-',
#  '-',
#  '₹ 1,195.00',
#  '₹ 569.00',
#  '₹ 659.00',
#  '₹ 449.00',
#  '₹ 399.00',
#  '₹ 349.00',
#  '-',
#  '-',
#  '₹ 367.00',
#  '₹ 339.00',
#  '₹ 379.00',
#  '-',
#  '₹ 1,095.00',
#  '₹ 699.00',
#  'Inclusive of all taxes',
#  '-',
#  '-',
#  '₹ 479.00',
#  '₹ 1,995.00',
#  '-',
#  '₹ 329.00',
#  '₹ 369.00',
#  '-',
#  '₹ 449.00',
#  '-',
#  '₹ 11,580.00',
#  '₹ 325.00',
#  '₹ 599.00',
#  '-',
#  '-',
#  'Inclusive of all taxes',
#  '-',
#  '-',
#  '₹ 536.00',
#  'Inclusive of all taxes',
#  '₹ 377.00',
#  '₹ 512.00',
#  '₹ 349.00',
#  '-',
#  '₹ 499.00',
#  '₹ 599.00',
#  '-',
#  '₹ 155.00',
#  '-',
#  '₹ 439.00',
#  '₹ 249.00',
#  '-',
#  '-',
#  '-',
#  '₹ 699.00',
#  '₹ 598.00',
#  '₹ 118.00',
#  '₹ 445.00',
#  '₹ 250.00',
#  '-',
#  '₹ 369.00',
#  '-',
#  '₹ 1,908.00',
# ...

# %%
print(len(Brand_Name),len(Name_of_the_Product),len(Rating),len(Return_Exchange),len(Availability),len(delivery),len(Price))
# Out:
# 138 138 138 138 137 137 137

# %%
df = pd.DataFrame({})
df["Brand"] =  Brand_Name[0:137]
df["product"] = Name_of_the_Product[0:137]
df["Rating"] = Rating[0:137]
df["Return/Exchange"] = Return_Exchange[0:137]
df["Availability"] = Availability
df["Delivery"] = delivery
df["Price"] = Price

# %%
df
# Out:
#                           Brand  \
# 0                      Brand: A
# 1                      Brand: A
# 2    Visit the EDDY HAGER Store
# 3                Brand: Generic
# 4      Visit the TIMEWEAR Store
# ..                          ...
# 132      Visit the Sonata Store
# 133       Visit the Casio Store
# 134                Brand: ILOFT
# 135     Visit the PANKATI Store
# 136             Brand: Fastrack
#
#                                                product        Rating  \
# 0    Acnos Brand - A Full Black Stailess Steel Case...  4.2 out of 5
# 1    Acnos Brand - A Full Black Stailess Steel Case...  4.2 out of 5
# 2    EDDY HAGER Time Teacher - Analogue Men's Watch...  3.9 out of 5
# 3    Shoppers4u Bluetooth Wireless Smart Fitness Ba...    3 out of 5
# 4         TIMEWEAR Analog Two Hands Slim Watch for Men  3.9 out of 5
# ..                                                 ...           ...
# 132  Sonata Formal Analog Black Dial Men's Watch NM...  4.2 out of 5
# ...

# %%
df["Brand"]=df["Brand"].str.strip("Visit the")

# %%
df["Brand"]=df["Brand"].str.strip("Store")

# %%
df["Brand"]=df["Brand"].str.strip("Brand:")

# %%
df
# Out:
#            Brand                                            product  \
# 0              A  Acnos Brand - A Full Black Stailess Steel Case...
# 1              A  Acnos Brand - A Full Black Stailess Steel Case...
# 2    EDDY HAGER   EDDY HAGER Time Teacher - Analogue Men's Watch...
# 3        Generic  Shoppers4u Bluetooth Wireless Smart Fitness Ba...
# 4      TIMEWEAR        TIMEWEAR Analog Two Hands Slim Watch for Men
# ..           ...                                                ...
# 132          ta   Sonata Formal Analog Black Dial Men's Watch NM...
# 133       Casio   Casio Enticer Men Analog Gold Dial Men's Watch...
# 134        ILOFT  ILOFT Charging Cable Adapter for Realme Fashio...
# 135     PANKATI   PANKATI Wrist Watch Storage Box Display Case O...
# 136     Fastrack  Fastrack Trendies Analog Black Dial Men's Watc...
#
#            Rating      Return/Exchange  \
# 0    4.2 out of 5      1 Year Warranty
# 1    4.2 out of 5      1 Year Warranty
# ...

# %%
driver.close()

# %% [markdown]
# # Q3)

# %%
import os
from PIL import Image
import io
from selenium.common.exceptions import ElementClickInterceptedException

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = 'https://images.google.com/?gws_rd=ssl'
driver.get(url)

# %%
search_bar = driver.find_element_by_xpath("//input[@class = 'gLFyf gsfi']")
search_bar.send_keys("fruits")
search_button = driver.find_element_by_xpath("//div[@class='FAuhyb']")
search_button.click()

# %%
# keep scrolling down the webpage untill it cannot scroll no more
for i in range(500):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
images =  driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")

# %%
img_urls = []
img_data = []

# %%
# getting the url of each images
for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)

# %%
#downloading all images
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images".format(i,100)) 
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\USER\scrap image"+ str(i)+".jpg","wb")
    file.write(response.content)

# %%
driver.close()

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = 'https://images.google.com/?gws_rd=ssl'
driver.get(url)

# %%
search_bar = driver.find_element_by_xpath("//input[@class = 'gLFyf gsfi']")
search_bar.send_keys("cars")
search_button = driver.find_element_by_xpath("//div[@class='FAuhyb']")
search_button.click()

# %%
for i in range(500):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
images = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")

# %%
img_urls=[]
for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)

# %%
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images".format(i,100)) 
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\USER\Downloads\cars_img"+ str(i)+".jpg","wb")
    file.write(response.content)

# %%
driver.close()

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = 'https://images.google.com/?gws_rd=ssl'
driver.get(url)

# %%
search_bar = driver.find_element_by_xpath("//input[@class = 'gLFyf gsfi']")
search_bar.send_keys("Machine Learning")
search_button = driver.find_element_by_xpath("//div[@class='FAuhyb']")
search_button.click()

# %%
for i in range(500):
    driver.execute_script("window.scrollBy(0,10000)")

images =  driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")

# %%
img_urls=[]
for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)

# %%
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images".format(i,100)) 
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\USER\Downloads\cars_img"+ str(i)+".jpg","wb")
    file.write(response.content)

# %%
driver.close()

# %% [markdown]
# # Q4)

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = 'http://www.flipkart.com/'
driver.get(url)

# %%
button=driver.find_element_by_xpath("//button[@class = '_2KpZ6l _2doB4z']").click()

# %%
search_bar = driver.find_element_by_name('q').send_keys("Oneplus Nord")
search=driver.find_element_by_class_name("L0Z3Pu").click()

# %%
urls = []
url = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
for i in url:
    urls.append(i.get_attribute("href"))

# %%
urls
# Out:
# ['https://www.flipkart.com/poco-m3-cool-blue-64-gb/p/itmc8ec867cb0472?pid=MOBFZTCUDDCTDN3G&lid=LSTMOBFZTCUDDCTDN3GJBLKQ8&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=SEARCH&iid=29cd2415-15c0-43d6-bba4-8d88cc67c429.MOBFZTCUDDCTDN3G.SEARCH&ppt=hp&ppn=homepage&ssid=yc14okj3ls0000001623083160082&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/redmi-9i-midnight-black-64-gb/p/itm0e1018dac2627?pid=MOBFV8RYKWQ3HACE&lid=LSTMOBFV8RYKWQ3HACEV2QOWQ&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=SEARCH&iid=29cd2415-15c0-43d6-bba4-8d88cc67c429.MOBFV8RYKWQ3HACE.SEARCH&ppt=hp&ppn=homepage&ssid=yc14okj3ls0000001623083160082&qH=1036ba3c4ed2c021',
# ...

# %%
brand_name=[]
smartphone_name=[]
color=[]
RAM=[]
ROM=[]
primary_camera=[]
secondary_camera=[]
display_size=[]
display_resolution=[]
processor=[]
processor_cores=[]
battery_capacity=[]
price=[]

# %%
for i in urls:
    driver.get(i)
    time.sleep(4)
    try:
        driver.find_element_by_xpath("//button[@class ='_2KpZ6l _1FH0tX']").click()
    except NoSuchElementException:
        print("exception occured.Move to next page")
        
    try:
        b = driver.find_element_by_xpath("//span[@class='B_NuCI']")
        brand_name.append(b.text)
    except NoSuchElementException:
        brand_name.append("--")
        
    brand_name = [x.split()[0] for x in brand_name]
    
    try:
        model = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div/div[1]/table/tbody/tr[3]/td[1]')
        if model.text != "Model Name":
            model = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div/div[1]/table/tbody/tr[2]/td[1]')
            if model.text != "Model Name":
                raise NoSuchElementException
            else:
                name = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div/div[1]/table/tbody/tr[2]/td[2]/ul/li')
        else:
            name = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div/div[1]/table/tbody/tr[3]/td[2]/ul/li')
        smartphone_name.append(name.text)
    except NoSuchElementException:
        smartphone_name.append('-')
        
        
    try: 
        if driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[3]/table/tbody/tr[3]/td[1]').text!= "Processor Core":
            if driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[3]/table/tbody/tr[2]/td[1]').text != "Processor Core":
                raise NoSuchElementException
            else:
                pr = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[3]/table/tbody/tr[2]/td[2]/ul/li')
                
        else:
            pr = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[3]/table/tbody/tr[3]/td[2]/ul/li')
        processor_cores.append(pr.text)
    except NoSuchElementException:
        processor_cores.append('-')
        
        
    try:
        k = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        price.append(k.text)
    except NoSuchElementException:
        price.append('-')
        
        
    try:
        model = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[1]')
        if model.text != "RAM":
            model = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[4]/table/tbody/tr[1]/td[1]')
            if model.text != "Model Name":
                raise NoSuchElementException
            else:
                rm = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[4]/table/tbody/tr[1]/td[2]/ul/li')
        else:
            rm = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]/ul/li')
        RAM.append(rm.text)
    except NoSuchElementException:
        RAM.append('-')   
    
    
    try:
        model = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[2]/td[1]')
        if model.text != "Primary Camera":
            model = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[1]/td[1]')
            if model.text != "Primary Camera":
                raise NoSuchElementException
            else:
                pc = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[1]/td[2]/ul/li')
        else:
            pc = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[2]/td[2]/ul/li')
        primary_camera.append(pc.text)
    except NoSuchElementException:
        primary_camera.append('-')   
        
        
    try:
        model = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[5]/td[1]')
        if model.text != "Secondary Camera":
            model = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[4]/td[1]')
            if model.text != "Secondary Camera":
                raise NoSuchElementException
            else:
                sc = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[4]/td[2]/ul/li')
        else:
            sc = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[5]/td[2]/ul/li')
        secondary_camera.append(sc.text)
    except NoSuchElementException:
        secondary_camera.append('-')

# %%
primary_camera
# Out:
# ['-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '13MP + 2MP + 2MP',
#  '13MP + 2MP + 2MP',
#  '13MP + 2MP + 2MP',
#  '48MP + 8MP + 2MP + 2MP',
#  '-',
#  '-',
#  '13MP + 2MP + 2MP',
#  '-']

# %%
secondary_camera
# Out:
# ['-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '-',
#  '-',
#  '-',
#  '8MP Front Camera',
#  '-']

# %%
processor_cores
# Out:
# ['-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Octa Core',
#  '-',
#  '-',
#  'Octa Core',
#  'Octa Core',
#  'Octa Core',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Octa Core']

# %%
smartphone_name
# Out:
# ['M3',
#  '9i',
#  'M3',
#  '9i',
#  '9i',
#  'Narzo 30A',
#  'Narzo 30A',
#  'Narzo 30A',
#  'C20',
#  'C20',
#  'M3',
#  'C12',
#  'C12',
#  '-',
#  'Max',
#  'Max',
#  '-',
#  '-',
#  '-',
#  '-',
#  '8 5G',
#  'Max',
#  'X3',
#  '-']

# %%
RAM
# Out:
# ['6 GB',
#  '4 GB',
#  '6 GB',
#  '4 GB',
#  '4 GB',
#  '3 GB',
#  '4 GB',
#  '3 GB',
#  '2 GB',
#  '2 GB',
#  '6 GB',
#  '3 GB',
#  '3 GB',
#  '-',
#  '2 GB',
#  '2 GB',
#  '-',
#  '-',
#  '-',
#  '-',
#  '4 GB',
#  '2 GB',
#  '6 GB',
#  '-']

# %%
df =pd. DataFrame({})
df["Brand_name"] = brand_name
df["Product_Name"] = smartphone_name
#df["color"] = color
df["RAM"] = RAM
df["Price"] = price
#df["ROM"] = ROM
df["Primary camera"] = primary_camera
df["Secondary camera"] = secondary_camera
#df["Display_size"] = display_size
#df["Display_resolution"] = display_resolution
#df["Processor"] = processor
df["Processor_core"] = processor_cores
#df["Battery_Capacity"] = battery_capacity
df["URL"] = urls
df
# Out:
#    Brand_name Product_Name   RAM    Price          Primary camera  \
# 0        POCO           M3  6 GB  ₹10,499                       -
# 1       REDMI           9i  4 GB   ₹7,999                       -
# 2        POCO           M3  6 GB  ₹10,499                       -
# 3      realme            -     -   ₹9,999                       -
# 4       REDMI           9i  4 GB   ₹7,999                       -
# 5      realme    Narzo 30A  3 GB   ₹7,999                       -
# 6      realme    Narzo 30A  4 GB   ₹8,999                       -
# 7      realme    Narzo 30A  3 GB   ₹7,999                       -
# 8       REDMI           9i  4 GB   ₹7,999                       -
# 9      realme          C20  2 GB   ₹6,799                       -
# 10     realme          C20  2 GB   ₹6,799                       -
# 11     realme          C12  3 GB   ₹7,999                       -
# 12     realme          C12  3 GB   ₹7,999                       -
# ...

# %%
driver.close()

# %% [markdown]
# # Q6)

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = 'https://www.google.com/maps'
driver.get(url)

# %%
input_city = input("name of place:")
# Out:
# name of place:Bangalore

# %%
search_bar = driver.find_element_by_id("searchboxinput").send_keys(input_city)

# %%
driver.find_element_by_id("searchbox-searchbutton").click()

# %%
# getting the current url
url = driver.current_url
print(url)
# Out:
# https://www.google.com/maps/place/Bengaluru,+Karnataka/@12.9539974,77.6309395,10z/data=!3m1!4b1!4m5!3m4!1s0x3bae1670c9b44e6d:0xf8dfc3e8517e4fe0!8m2!3d12.9715987!4d77.5945627

# %%
# finding the latitude and longitude in the url

start = url.find("@") + len("@")
end = url.find("z")
substring = url[start:end]
latitude = substring.split(",")[0]
longitude = substring.split(",")[1]
# printing latitude and longitude
print("latitude:",latitude)
print("longitude",longitude)
# Out:
# latitude: 12.9539974
# longitude 77.6309395

# %%
driver.close()

# %% [markdown]
# # Q6)

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = 'https://trak.in/india-startup-funding-investment-2015/'
driver.get(url)

# %%
date = []
s_name = []
industry = []
sub =[]
location =[]
i_name =[]
i_type = []
amount = []

# %%
# getting the data of the month from july to september
for i in range(48,51):
    # date
    dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        date.append(d.text)
        
    # startupname
    s = driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for d in s:
        s_name.append(d.text)
        
    #industry
    a = driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for d in a:
        industry.append(d.text)
        
    #sub
    su = driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for d in su:
        sub.append(d.text)
        
    #location
    lo = driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for d in lo:
        location.append(d.text)
        
    #i_name
    ina = driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for d in ina:
        i_name.append(d.text)
       
    #i_type
    ty = driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for d in ty:
        i_type.append(d.text)
        
    # amount
    am = driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for d in am:
        amount.append(d.text)

# %%
print(len(date),len(s_name),len(industry),len(sub),len(location),len(i_name),len(i_type),len(amount))
# Out:
# 30 30 30 30 30 30 30 30

# %%
df1 =pd.DataFrame({})
df1["Date"] = date
df1["Startup_Name"] = s_name
df1["Industry"] = industry
df1["Sub"] = sub
df1["Location"] = location
df1["Investors name"] = i_name
df1["Investment_type"] = i_type
df1["Amount"] = amount
df1
# Out:
#           Date               Startup_Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# ...

# %%
driver.close()

# %% [markdown]
# # Q7)

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = 'https://www.digit.in/top-products/best-gaming-laptops-40.html'
driver.get(url)

# %%
title = driver.find_elements_by_xpath("//div[@class='TopNumbeHeading active sticky-footer']")
title
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="2bf232f2-00d6-4dea-8bbd-64b547603ef3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="0f5ea98f-7fdf-4842-ae18-8d9bfd003234")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="587c2e41-1099-4cb7-ab4b-bdac160785c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="8568dacb-6ed5-4a81-bcab-39d27c5bc4c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="6ee365a5-0dd6-43c6-a366-17c247e85307")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="063e0c7a-d19d-484c-a891-0d4e575ac171")>,
# ...

# %%
titles =[]
for i in title:
    titles.append(i.text.replace('\n',''))
titles
# Out:
# ['1.ALIENWARE AREA 51M R2',
#  '2.ALIENWARE M15 R3',
#  '3.ASUS ROG STRIX SCAR 15',
#  '4.ASUS ROG ZEPHYRUS G14',
#  '5.LENOVO LEGION 5I',
#  '6.ASUS ROG ZEPHYRUS DUO 15',
#  '7.ACER ASPIRE 7 GAMING']

# %%
os = driver.find_elements_by_xpath("//div[@class='value']")
os
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="88c8fda4-294e-4e7d-b43b-6da3d3ad4fb4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="1776a1bb-ea21-4c7e-a362-c2c7e02ad3c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="8ba84a50-6836-4ce4-9c2a-de5fc11c86b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="05a56498-35e4-4bcb-9394-97ae9bc00d5a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="6cc86918-27d0-4396-b6c1-647368086cb8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="216f126d5bcbb378ce3850d4998199d6", element="41fc881a-f310-4566-867e-36e6cb43d560")>,
# ...

# %%
OS =[]
for i in os:
    OS.append(i.text.replace('\n',''))
OS
# Out:
# ['WINDOWS 10 HOME',
#  '17.3" (1920 X 1080)',
#  '10TH GENERATION INTEL® CORE™ I7-10700 | 2.90 GHZ',
#  '1 TB SSD/16 GBGB DDR4',
#  'WINDOWS 10 HOME',
#  '15.6" (3840 X 2160)',
#  '10TH GENERATION INTEL® CORE™ I9-10980HK | NA',
#  '1 TB SSD/16 GBGB DDR4',
#  'WINDOWS 10 HOME',
#  '15.6" (1920 X 1080)',
#  'AMD RYZEN™ 9 5900HX | 3.3 GHZ',
#  '1 TB SSD/16 GBGB DDR4',
#  'WINDOWS 10 HOME',
#  '14" (1920 X 1080)',
#  'AMD 3RD GENERATION RYZEN 9 | 3.3 GHZ',
#  '1 TB SSD/16 GBGB DDR4',
#  'WINDOWS 10 PRO',
#  '15.6" (1920 X 1080)',
#  '10TH GENERATION INTEL® CORE™ I5-10300H | 2.50 GHZ',
#  '1 TB SSD/16 GBGB DDR4',
#  'WINDOWS 10',
#  '15.6" (3840 X 1100)',
#  'INTEL CORE I7 10TH GEN 10875H | NA',
#  '512 GB SSD/4 GBGB DDR4',
#  'WINDOWS 10 HOME',
#  '15.6" (1920 X 1080)',
#  'AMD RYZEN™ 5-5500U HEXA-CORE | NA',
#  '512 GB SSD/8 GBGB DDR4']

# %%
o = OS[0:25:4]

# %%
o
# Out:
# ['WINDOWS 10 HOME',
#  'WINDOWS 10 HOME',
#  'WINDOWS 10 HOME',
#  'WINDOWS 10 HOME',
#  'WINDOWS 10 PRO',
#  'WINDOWS 10',
#  'WINDOWS 10 HOME']

# %%
display=OS[1:26:4]
display
# Out:
# ['17.3" (1920 X 1080)',
#  '15.6" (3840 X 2160)',
#  '15.6" (1920 X 1080)',
#  '14" (1920 X 1080)',
#  '15.6" (1920 X 1080)',
#  '15.6" (3840 X 1100)',
#  '15.6" (1920 X 1080)']

# %%
processor=OS[2:27:4]
processor
# Out:
# ['10TH GENERATION INTEL® CORE™ I7-10700 | 2.90 GHZ',
#  '10TH GENERATION INTEL® CORE™ I9-10980HK | NA',
#  'AMD RYZEN™ 9 5900HX | 3.3 GHZ',
#  'AMD 3RD GENERATION RYZEN 9 | 3.3 GHZ',
#  '10TH GENERATION INTEL® CORE™ I5-10300H | 2.50 GHZ',
#  'INTEL CORE I7 10TH GEN 10875H | NA',
#  'AMD RYZEN™ 5-5500U HEXA-CORE | NA']

# %%
memory=OS[3:28:4]
memory
# Out:
# ['1 TB SSD/16 GBGB DDR4',
#  '1 TB SSD/16 GBGB DDR4',
#  '1 TB SSD/16 GBGB DDR4',
#  '1 TB SSD/16 GBGB DDR4',
#  '1 TB SSD/16 GBGB DDR4',
#  '512 GB SSD/4 GBGB DDR4',
#  '512 GB SSD/8 GBGB DDR4']

# %%
price=[]
p = driver.find_elements_by_xpath("//td[@class='smprice']")
try:
    for i in p:
        price.append(i.text)
except NoSuchElementException:
    price.append('--')

# %%
price
# Out:
# ['N/A', '₹341990', 'N/A', '₹164990', '₹71990', '₹199990', '₹56990']

# %%
df = pd.DataFrame({})
df["Title"] = titles
df["OS"] = o
df["Display"] = display
df["Processor"] = processor
df["Memory"] = memory
df["Price"] = price
df
# Out:
#                         Title               OS              Display  \
# 0     1.ALIENWARE AREA 51M R2  WINDOWS 10 HOME  17.3" (1920 X 1080)
# 1          2.ALIENWARE M15 R3  WINDOWS 10 HOME  15.6" (3840 X 2160)
# 2    3.ASUS ROG STRIX SCAR 15  WINDOWS 10 HOME  15.6" (1920 X 1080)
# 3     4.ASUS ROG ZEPHYRUS G14  WINDOWS 10 HOME    14" (1920 X 1080)
# 4          5.LENOVO LEGION 5I   WINDOWS 10 PRO  15.6" (1920 X 1080)
# 5  6.ASUS ROG ZEPHYRUS DUO 15       WINDOWS 10  15.6" (3840 X 1100)
# 6      7.ACER ASPIRE 7 GAMING  WINDOWS 10 HOME  15.6" (1920 X 1080)
#
#                                            Processor                  Memory  \
# 0   10TH GENERATION INTEL® CORE™ I7-10700 | 2.90 GHZ   1 TB SSD/16 GBGB DDR4
# 1       10TH GENERATION INTEL® CORE™ I9-10980HK | NA   1 TB SSD/16 GBGB DDR4
# 2                      AMD RYZEN™ 9 5900HX | 3.3 GHZ   1 TB SSD/16 GBGB DDR4
# 3               AMD 3RD GENERATION RYZEN 9 | 3.3 GHZ   1 TB SSD/16 GBGB DDR4
# ...

# %%
driver.close()
